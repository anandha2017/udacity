# %%
from __future__ import print_function

from keras import backend as K
K.set_image_dim_ordering('th') # ensure our dimension notation matches

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Convolution2D, AveragePooling2D
from keras.layers.core import Flatten
from keras.optimizers import SGD, Adam
from keras.datasets import mnist
from keras import utils
import numpy as np
from PIL import Image, ImageOps
import argparse
import math

import os
import os.path

import glob
# Out:
# Using TensorFlow backend.

# %%
def generator_model():
    model = Sequential()
    model.add(Dense(input_dim=100, output_dim=1024))
    model.add(Activation('tanh'))
    model.add(Dense(128*8*8))
    model.add(BatchNormalization())
    model.add(Activation('tanh'))
    model.add(Reshape((128, 8, 8), input_shape=(128*8*8,)))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(64, 5, 5, border_mode='same'))
    model.add(Activation('tanh'))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(1, 5, 5, border_mode='same'))
    model.add(Activation('tanh'))
    return model


def discriminator_model():
    model = Sequential()
    model.add(Convolution2D(
                        64, 5, 5,
                        border_mode='same',
                        input_shape=(1, 128, 128)))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(4, 4)))
    model.add(Convolution2D(128, 5, 5))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(256))
    model.add(Activation('tanh'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    return model


def generator_containing_discriminator(generator, discriminator):
    model = Sequential()
    model.add(generator)
    discriminator.trainable = False
    model.add(discriminator)
    return model


def combine_images(generated_images):
    num = generated_images.shape[0]
    width = int(math.sqrt(num))
    height = int(math.ceil(float(num)/width))
    shape = generated_images.shape[2:]
    image = np.zeros((height*shape[0], width*shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = \
            img[0, :, :]
    return image

# %%
model = generator_model()
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              103424
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8192)              8396800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8192)              32768
# _________________________________________________________________
# activation_2 (Activation)    (None, 8192)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 128, 8, 8)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 32, 32)        204864
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 32, 32)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 128, 128)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 128, 128)       1601
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 128, 128)       0
# =================================================================
# Total params: 8,739,457
# Trainable params: 8,723,073
# Non-trainable params: 16,384
# _________________________________________________________________
# None
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]

# %%
def load_data(pixels=128, verbose=False):
    print("Loading data")
    X_train = []
    paths = glob.glob(os.path.normpath(os.getcwd() + '/logos/*.jpg'))
    for path in paths:
        if verbose: print(path)
        im = Image.open(path)
        im = ImageOps.fit(im, (pixels, pixels), Image.ANTIALIAS)
        im = ImageOps.grayscale(im)
        #im.show()
        im = np.asarray(im)
        X_train.append(im)
    print("Finished loading data")
    return np.array(X_train)

def train(epochs, BATCH_SIZE, weights=False):
    """
    :param epochs: Train for this many epochs
    :param BATCH_SIZE: Size of minibatch
    :param weights: If True, load weights from file, otherwise train the model from scratch. 
    Use this if you have already saved state of the network and want to train it further.
    """
    X_train = load_data()
    X_train = (X_train.astype(np.float32) - 127.5)/127.5
    X_train = X_train.reshape((X_train.shape[0], 1) + X_train.shape[1:])
    discriminator = discriminator_model()
    generator = generator_model()
    if weights:
        generator.load_weights('goodgenerator.h5')
        discriminator.load_weights('gooddiscriminator.h5')
    discriminator_on_generator = \
        generator_containing_discriminator(generator, discriminator)
    d_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    g_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    discriminator_on_generator.compile(
        loss='binary_crossentropy', optimizer=g_optim)
    discriminator.trainable = True
    discriminator.compile(loss='binary_crossentropy', optimizer=d_optim)
    noise = np.zeros((BATCH_SIZE, 100))
    for epoch in range(epochs):
        print("Epoch is", epoch)
        print("Number of batches", int(X_train.shape[0]/BATCH_SIZE))
        for index in range(int(X_train.shape[0]/BATCH_SIZE)):
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            image_batch = X_train[index*BATCH_SIZE:(index+1)*BATCH_SIZE]
            generated_images = generator.predict(noise, verbose=0)
            #print(generated_images.shape)
            if index % 20 == 0 and epoch % 10 == 0:
                image = combine_images(generated_images)
                image = image*127.5+127.5
                destpath = os.path.normpath(os.getcwd()+ "/logo-generated-images/"+str(epoch)+"_"+str(index)+".png")
                Image.fromarray(image.astype(np.uint8)).save(destpath)
            X = np.concatenate((image_batch, generated_images))
            y = [1] * BATCH_SIZE + [0] * BATCH_SIZE
            d_loss = discriminator.train_on_batch(X, y)
            print("batch %d d_loss : %f" % (index, d_loss))
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            discriminator.trainable = False
            g_loss = discriminator_on_generator.train_on_batch(
                noise, [1] * BATCH_SIZE)
            discriminator.trainable = True
            print("batch %d g_loss : %f" % (index, g_loss))
            if epoch % 10 == 9:
                generator.save_weights('goodgenerator.h5', True)
                discriminator.save_weights('gooddiscriminator.h5', True)

def clean(image):
    for i in range(1, image.shape[0] - 1):
        for j in range(1, image.shape[1] - 1):
            if image[i][j] + image[i+1][j] + image[i][j+1] + image[i-1][j] + image[i][j-1] > 127 * 5:
                image[i][j] = 255
    return image
def generate(BATCH_SIZE):
    generator = generator_model()
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    generator.load_weights('goodgenerator.h5')
    noise = np.zeros((BATCH_SIZE, 100))
    a = np.random.uniform(-1, 1, 100)
    b = np.random.uniform(-1, 1, 100)
    grad = (b - a) / BATCH_SIZE
    for i in range(BATCH_SIZE):
        noise[i, :] = np.random.uniform(-1, 1, 100)
    generated_images = generator.predict(noise, verbose=1)
    #image = combine_images(generated_images)
    print(generated_images.shape)
    for image in generated_images:
        image = image[0]
        image = image*127.5+127.5
        Image.fromarray(image.astype(np.uint8)).save("dirty.png")
        Image.fromarray(image.astype(np.uint8)).show()
        clean(image)
        image = Image.fromarray(image.astype(np.uint8))
        image.show()        
        image.save("clean.png")


def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument("--mode", type=str)
    parser.add_argument("--batch_size", type=int, default=128)
    parser.add_argument("--nice", dest="nice", action="store_true")
    parser.set_defaults(nice=False)
    args = parser.parse_args()
    return args

# %%
train(400, 10, False)
# Out:
# Loading data
# Finished loading data
# Epoch is 0
# Number of batches 3
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), input_shape=(1, 128, 1..., padding="same")`
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (5, 5))`
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]
# batch 0 d_loss : 0.625051
# batch 0 g_loss : 0.699870
# batch 1 d_loss : 0.598545
# batch 1 g_loss : 0.685610
# batch 2 d_loss : 0.559805
# batch 2 g_loss : 0.688802
# Epoch is 1
# Number of batches 3
# batch 0 d_loss : 0.539188
# batch 0 g_loss : 0.686688
# batch 1 d_loss : 0.500435
# batch 1 g_loss : 0.700071
# batch 2 d_loss : 0.472255
# batch 2 g_loss : 0.705819
# Epoch is 2
# Number of batches 3
# batch 0 d_loss : 0.460865
# batch 0 g_loss : 0.701458
# batch 1 d_loss : 0.432658
# batch 1 g_loss : 0.699923
# batch 2 d_loss : 0.408938
# batch 2 g_loss : 0.709426
# Epoch is 3
# Number of batches 3
# batch 0 d_loss : 0.410810
# batch 0 g_loss : 0.696483
# batch 1 d_loss : 0.403814
# batch 1 g_loss : 0.698115
# batch 2 d_loss : 0.409418
# batch 2 g_loss : 0.703899
# Epoch is 4
# Number of batches 3
# batch 0 d_loss : 0.413991
# batch 0 g_loss : 0.683681
# batch 1 d_loss : 0.418286
# batch 1 g_loss : 0.681528
# batch 2 d_loss : 0.424411
# batch 2 g_loss : 0.697399
# Epoch is 5
# Number of batches 3
# batch 0 d_loss : 0.422089
# batch 0 g_loss : 0.661628
# batch 1 d_loss : 0.423632
# batch 1 g_loss : 0.648105
# batch 2 d_loss : 0.445086
# batch 2 g_loss : 0.702213
# Epoch is 6
# Number of batches 3
# batch 0 d_loss : 0.469619
# batch 0 g_loss : 0.657063
# batch 1 d_loss : 0.484568
# batch 1 g_loss : 0.667713
# batch 2 d_loss : 0.481951
# batch 2 g_loss : 0.671668
# Epoch is 7
# Number of batches 3
# batch 0 d_loss : 0.484873
# batch 0 g_loss : 0.628990
# batch 1 d_loss : 0.494274
# batch 1 g_loss : 0.642383
# batch 2 d_loss : 0.534823
# batch 2 g_loss : 0.646819
# Epoch is 8
# Number of batches 3
# batch 0 d_loss : 0.519300
# batch 0 g_loss : 0.657712
# batch 1 d_loss : 0.517676
# batch 1 g_loss : 0.619494
# batch 2 d_loss : 0.533011
# batch 2 g_loss : 0.649121
# Epoch is 9
# Number of batches 3
# batch 0 d_loss : 0.548111
# batch 0 g_loss : 0.666279
# batch 1 d_loss : 0.527452
# batch 1 g_loss : 0.656299
# batch 2 d_loss : 0.520941
# batch 2 g_loss : 0.656341
# Epoch is 10
# Number of batches 3
# batch 0 d_loss : 0.516644
# batch 0 g_loss : 0.688660
# batch 1 d_loss : 0.513072
# batch 1 g_loss : 0.721271
# batch 2 d_loss : 0.510540
# batch 2 g_loss : 0.727845
# Epoch is 11
# Number of batches 3
# batch 0 d_loss : 0.503300
# batch 0 g_loss : 0.751831
# batch 1 d_loss : 0.483259
# batch 1 g_loss : 0.747434
# batch 2 d_loss : 0.479721
# batch 2 g_loss : 0.784219
# Epoch is 12
# Number of batches 3
# batch 0 d_loss : 0.484739
# batch 0 g_loss : 0.795097
# batch 1 d_loss : 0.464233
# batch 1 g_loss : 0.796460
# batch 2 d_loss : 0.465012
# batch 2 g_loss : 0.858558
# Epoch is 13
# Number of batches 3
# batch 0 d_loss : 0.467533
# batch 0 g_loss : 0.874319
# batch 1 d_loss : 0.457521
# batch 1 g_loss : 0.889799
# batch 2 d_loss : 0.458467
# batch 2 g_loss : 0.890477
# Epoch is 14
# Number of batches 3
# batch 0 d_loss : 0.466051
# batch 0 g_loss : 0.947125
# batch 1 d_loss : 0.452576
# batch 1 g_loss : 0.918608
# batch 2 d_loss : 0.449392
# batch 2 g_loss : 0.938093
# Epoch is 15
# Number of batches 3
# batch 0 d_loss : 0.447489
# batch 0 g_loss : 0.954487
# batch 1 d_loss : 0.444698
# batch 1 g_loss : 0.964346
# batch 2 d_loss : 0.429853
# batch 2 g_loss : 0.970672
# Epoch is 16
# Number of batches 3
# batch 0 d_loss : 0.435716
# batch 0 g_loss : 0.997705
# batch 1 d_loss : 0.433653
# batch 1 g_loss : 1.016691
# batch 2 d_loss : 0.418268
# batch 2 g_loss : 1.006921
# Epoch is 17
# Number of batches 3
# batch 0 d_loss : 0.419525
# batch 0 g_loss : 1.021392
# batch 1 d_loss : 0.409558
# batch 1 g_loss : 1.006359
# batch 2 d_loss : 0.390775
# batch 2 g_loss : 1.023098
# Epoch is 18
# Number of batches 3
# batch 0 d_loss : 0.393897
# batch 0 g_loss : 1.046216
# batch 1 d_loss : 0.383909
# batch 1 g_loss : 1.068708
# batch 2 d_loss : 0.379018
# batch 2 g_loss : 1.077410
# Epoch is 19
# Number of batches 3
# batch 0 d_loss : 0.379628
# batch 0 g_loss : 1.094028
# batch 1 d_loss : 0.367184
# batch 1 g_loss : 1.085362
# batch 2 d_loss : 0.345778
# batch 2 g_loss : 1.133765
# Epoch is 20
# Number of batches 3
# batch 0 d_loss : 0.357801
# batch 0 g_loss : 1.098779
# batch 1 d_loss : 0.352078
# batch 1 g_loss : 1.116140
# batch 2 d_loss : 0.321232
# batch 2 g_loss : 1.170574
# Epoch is 21
# Number of batches 3
# batch 0 d_loss : 0.345975
# batch 0 g_loss : 1.197804
# batch 1 d_loss : 0.327687
# batch 1 g_loss : 1.144994
# batch 2 d_loss : 0.303389
# batch 2 g_loss : 1.237763
# Epoch is 22
# Number of batches 3
# batch 0 d_loss : 0.311866
# batch 0 g_loss : 1.234984
# batch 1 d_loss : 0.309750
# batch 1 g_loss : 1.253969
# batch 2 d_loss : 0.280245
# batch 2 g_loss : 1.216073
# Epoch is 23
# Number of batches 3
# batch 0 d_loss : 0.301067
# batch 0 g_loss : 1.315083
# batch 1 d_loss : 0.284164
# batch 1 g_loss : 1.309435
# batch 2 d_loss : 0.252211
# batch 2 g_loss : 1.319500
# Epoch is 24
# Number of batches 3
# batch 0 d_loss : 0.280756
# batch 0 g_loss : 1.382730
# batch 1 d_loss : 0.276798
# batch 1 g_loss : 1.361727
# batch 2 d_loss : 0.234101
# batch 2 g_loss : 1.387762
# Epoch is 25
# Number of batches 3
# batch 0 d_loss : 0.254646
# batch 0 g_loss : 1.412548
# batch 1 d_loss : 0.245794
# batch 1 g_loss : 1.378575
# batch 2 d_loss : 0.213433
# batch 2 g_loss : 1.459597
# Epoch is 26
# Number of batches 3
# batch 0 d_loss : 0.236309
# batch 0 g_loss : 1.491238
# batch 1 d_loss : 0.233776
# batch 1 g_loss : 1.375704
# batch 2 d_loss : 0.207716
# batch 2 g_loss : 1.499130
# Epoch is 27
# Number of batches 3
# batch 0 d_loss : 0.224405
# batch 0 g_loss : 1.505968
# batch 1 d_loss : 0.213593
# batch 1 g_loss : 1.545336
# batch 2 d_loss : 0.179964
# batch 2 g_loss : 1.541407
# Epoch is 28
# Number of batches 3
# batch 0 d_loss : 0.210272
# batch 0 g_loss : 1.519271
# batch 1 d_loss : 0.201776
# batch 1 g_loss : 1.638226
# batch 2 d_loss : 0.176648
# batch 2 g_loss : 1.578334
# Epoch is 29
# Number of batches 3
# batch 0 d_loss : 0.191668
# batch 0 g_loss : 1.530771
# batch 1 d_loss : 0.191253
# batch 1 g_loss : 1.608968
# batch 2 d_loss : 0.158125
# batch 2 g_loss : 1.578568
# Epoch is 30
# Number of batches 3
# batch 0 d_loss : 0.200226
# batch 0 g_loss : 1.553678
# batch 1 d_loss : 0.176135
# batch 1 g_loss : 1.684161
# batch 2 d_loss : 0.144371
# batch 2 g_loss : 1.745394
# Epoch is 31
# Number of batches 3
# batch 0 d_loss : 0.174073
# batch 0 g_loss : 1.642457
# batch 1 d_loss : 0.169902
# batch 1 g_loss : 1.619723
# batch 2 d_loss : 0.125792
# batch 2 g_loss : 1.633662
# Epoch is 32
# Number of batches 3
# batch 0 d_loss : 0.176087
# batch 0 g_loss : 1.768882
# batch 1 d_loss : 0.160049
# batch 1 g_loss : 1.803170
# batch 2 d_loss : 0.126576
# batch 2 g_loss : 1.751453
# Epoch is 33
# Number of batches 3
# batch 0 d_loss : 0.151862
# batch 0 g_loss : 1.515062
# batch 1 d_loss : 0.154805
# batch 1 g_loss : 1.776300
# batch 2 d_loss : 0.120412
# batch 2 g_loss : 1.652082
# Epoch is 34
# Number of batches 3
# batch 0 d_loss : 0.144535
# batch 0 g_loss : 1.664246
# batch 1 d_loss : 0.136580
# batch 1 g_loss : 1.566285
# batch 2 d_loss : 0.115230
# batch 2 g_loss : 1.686882
# Epoch is 35
# Number of batches 3
# batch 0 d_loss : 0.129415
# batch 0 g_loss : 1.514708
# batch 1 d_loss : 0.143119
# batch 1 g_loss : 1.604610
# batch 2 d_loss : 0.102621
# batch 2 g_loss : 1.711352
# Epoch is 36
# Number of batches 3
# batch 0 d_loss : 0.151315
# batch 0 g_loss : 1.638636
# batch 1 d_loss : 0.145400
# batch 1 g_loss : 1.560992
# batch 2 d_loss : 0.112185
# batch 2 g_loss : 1.867963
# Epoch is 37
# Number of batches 3
# batch 0 d_loss : 0.156605
# batch 0 g_loss : 1.716589
# batch 1 d_loss : 0.150460
# batch 1 g_loss : 1.447993
# batch 2 d_loss : 0.082610
# batch 2 g_loss : 1.648351
# Epoch is 38
# Number of batches 3
# batch 0 d_loss : 0.161162
# batch 0 g_loss : 1.923984
# batch 1 d_loss : 0.160326
# batch 1 g_loss : 1.644391
# batch 2 d_loss : 0.109801
# batch 2 g_loss : 1.662057
# Epoch is 39
# Number of batches 3
# batch 0 d_loss : 0.142753
# batch 0 g_loss : 1.661729
# batch 1 d_loss : 0.173304
# batch 1 g_loss : 1.796294
# batch 2 d_loss : 0.122435
# batch 2 g_loss : 1.591108
# Epoch is 40
# Number of batches 3
# batch 0 d_loss : 0.150370
# batch 0 g_loss : 1.667000
# batch 1 d_loss : 0.174634
# batch 1 g_loss : 1.636769
# batch 2 d_loss : 0.121876
# batch 2 g_loss : 1.358109
# Epoch is 41
# Number of batches 3
# batch 0 d_loss : 0.148706
# batch 0 g_loss : 1.658374
# batch 1 d_loss : 0.193259
# batch 1 g_loss : 1.259724
# batch 2 d_loss : 0.125092
# batch 2 g_loss : 1.188874
# Epoch is 42
# Number of batches 3
# batch 0 d_loss : 0.181333
# batch 0 g_loss : 1.490081
# batch 1 d_loss : 0.182581
# batch 1 g_loss : 1.481140
# batch 2 d_loss : 0.178946
# batch 2 g_loss : 1.392011
# Epoch is 43
# Number of batches 3
# batch 0 d_loss : 0.210728
# batch 0 g_loss : 1.272603
# batch 1 d_loss : 0.254320
# batch 1 g_loss : 1.443986
# batch 2 d_loss : 0.139218
# batch 2 g_loss : 1.516988
# Epoch is 44
# Number of batches 3
# batch 0 d_loss : 0.214623
# batch 0 g_loss : 1.674325
# batch 1 d_loss : 0.234204
# batch 1 g_loss : 1.263367
# batch 2 d_loss : 0.254914
# batch 2 g_loss : 1.894930
# Epoch is 45
# Number of batches 3
# batch 0 d_loss : 0.316669
# batch 0 g_loss : 1.373129
# batch 1 d_loss : 0.248516
# batch 1 g_loss : 1.644613
# batch 2 d_loss : 0.127281
# batch 2 g_loss : 1.809843
# Epoch is 46
# Number of batches 3
# batch 0 d_loss : 0.304113
# batch 0 g_loss : 1.330969
# batch 1 d_loss : 0.249917
# batch 1 g_loss : 1.321899
# batch 2 d_loss : 0.214623
# batch 2 g_loss : 1.933152
# Epoch is 47
# Number of batches 3
# batch 0 d_loss : 0.299843
# batch 0 g_loss : 1.768464
# batch 1 d_loss : 0.340470
# batch 1 g_loss : 1.028545
# batch 2 d_loss : 0.231616
# batch 2 g_loss : 1.651897
# Epoch is 48
# Number of batches 3
# batch 0 d_loss : 0.281073
# batch 0 g_loss : 2.039861
# batch 1 d_loss : 0.341879
# batch 1 g_loss : 1.704404
# batch 2 d_loss : 0.133553
# batch 2 g_loss : 1.251820
# Epoch is 49
# Number of batches 3
# batch 0 d_loss : 0.413473
# batch 0 g_loss : 1.429641
# batch 1 d_loss : 0.374572
# batch 1 g_loss : 1.447012
# batch 2 d_loss : 0.268208
# batch 2 g_loss : 1.536999
# Epoch is 50
# Number of batches 3
# batch 0 d_loss : 0.354723
# batch 0 g_loss : 1.160103
# batch 1 d_loss : 0.410004
# batch 1 g_loss : 1.469318
# batch 2 d_loss : 0.213541
# batch 2 g_loss : 1.279050
# Epoch is 51
# Number of batches 3
# batch 0 d_loss : 0.406701
# batch 0 g_loss : 1.759774
# batch 1 d_loss : 0.428837
# batch 1 g_loss : 1.672572
# batch 2 d_loss : 0.379982
# batch 2 g_loss : 1.565485
# Epoch is 52
# Number of batches 3
# batch 0 d_loss : 0.331342
# batch 0 g_loss : 1.364352
# batch 1 d_loss : 0.568414
# batch 1 g_loss : 1.492123
# batch 2 d_loss : 0.419954
# batch 2 g_loss : 1.761136
# Epoch is 53
# Number of batches 3
# batch 0 d_loss : 0.512784
# batch 0 g_loss : 1.791008
# batch 1 d_loss : 0.577661
# batch 1 g_loss : 2.091140
# batch 2 d_loss : 0.453250
# batch 2 g_loss : 1.704512
# Epoch is 54
# Number of batches 3
# batch 0 d_loss : 0.389243
# batch 0 g_loss : 1.906830
# batch 1 d_loss : 0.462130
# batch 1 g_loss : 1.545107
# batch 2 d_loss : 0.232670
# batch 2 g_loss : 1.077518
# Epoch is 55
# Number of batches 3
# batch 0 d_loss : 0.473264
# batch 0 g_loss : 1.915785
# batch 1 d_loss : 0.547989
# batch 1 g_loss : 1.398789
# batch 2 d_loss : 0.399903
# batch 2 g_loss : 1.592196
# Epoch is 56
# Number of batches 3
# batch 0 d_loss : 0.552559
# batch 0 g_loss : 2.204082
# batch 1 d_loss : 0.502237
# batch 1 g_loss : 1.433532
# batch 2 d_loss : 0.342422
# batch 2 g_loss : 1.662210
# Epoch is 57
# Number of batches 3
# batch 0 d_loss : 0.385495
# batch 0 g_loss : 1.392851
# batch 1 d_loss : 0.593888
# batch 1 g_loss : 1.247189
# batch 2 d_loss : 0.307606
# batch 2 g_loss : 1.864625
# Epoch is 58
# Number of batches 3
# batch 0 d_loss : 0.524927
# batch 0 g_loss : 1.560044
# batch 1 d_loss : 0.458692
# batch 1 g_loss : 1.633308
# batch 2 d_loss : 0.293498
# batch 2 g_loss : 1.968298
# Epoch is 59
# Number of batches 3
# batch 0 d_loss : 0.400726
# batch 0 g_loss : 1.994383
# batch 1 d_loss : 0.443945
# batch 1 g_loss : 1.728161
# batch 2 d_loss : 0.308049
# batch 2 g_loss : 1.730455
# Epoch is 60
# Number of batches 3
# batch 0 d_loss : 0.525780
# batch 0 g_loss : 1.704758
# batch 1 d_loss : 0.364357
# batch 1 g_loss : 1.817880
# batch 2 d_loss : 0.331271
# batch 2 g_loss : 1.991372
# Epoch is 61
# Number of batches 3
# batch 0 d_loss : 0.425342
# batch 0 g_loss : 1.541635
# batch 1 d_loss : 0.382081
# batch 1 g_loss : 1.782369
# batch 2 d_loss : 0.356352
# batch 2 g_loss : 1.991287
# Epoch is 62
# Number of batches 3
# batch 0 d_loss : 0.424194
# batch 0 g_loss : 2.421697
# batch 1 d_loss : 0.402386
# batch 1 g_loss : 1.445921
# batch 2 d_loss : 0.277627
# batch 2 g_loss : 1.957031
# Epoch is 63
# Number of batches 3
# batch 0 d_loss : 0.396478
# batch 0 g_loss : 1.741960
# batch 1 d_loss : 0.360669
# batch 1 g_loss : 1.906377
# batch 2 d_loss : 0.342510
# batch 2 g_loss : 2.053605
# Epoch is 64
# Number of batches 3
# batch 0 d_loss : 0.431375
# batch 0 g_loss : 2.125576
# batch 1 d_loss : 0.347356
# batch 1 g_loss : 1.785019
# batch 2 d_loss : 0.399783
# batch 2 g_loss : 1.948587
# Epoch is 65
# Number of batches 3
# batch 0 d_loss : 0.430898
# batch 0 g_loss : 1.851479
# batch 1 d_loss : 0.329250
# batch 1 g_loss : 2.019825
# batch 2 d_loss : 0.250179
# batch 2 g_loss : 1.609800
# Epoch is 66
# Number of batches 3
# batch 0 d_loss : 0.415095
# batch 0 g_loss : 1.783584
# batch 1 d_loss : 0.530291
# batch 1 g_loss : 2.041101
# batch 2 d_loss : 0.350269
# batch 2 g_loss : 2.244692
# Epoch is 67
# Number of batches 3
# batch 0 d_loss : 0.405482
# batch 0 g_loss : 1.832071
# batch 1 d_loss : 0.376205
# batch 1 g_loss : 1.807081
# batch 2 d_loss : 0.278071
# batch 2 g_loss : 2.014531
# Epoch is 68
# Number of batches 3
# batch 0 d_loss : 0.385164
# batch 0 g_loss : 2.083890
# batch 1 d_loss : 0.304491
# batch 1 g_loss : 1.561135
# batch 2 d_loss : 0.348030
# batch 2 g_loss : 1.748822
# Epoch is 69
# Number of batches 3
# batch 0 d_loss : 0.376477
# batch 0 g_loss : 1.556825
# batch 1 d_loss : 0.335963
# batch 1 g_loss : 1.495024
# batch 2 d_loss : 0.320854
# batch 2 g_loss : 1.419280
# Epoch is 70
# Number of batches 3
# batch 0 d_loss : 0.355639
# batch 0 g_loss : 1.995266
# batch 1 d_loss : 0.270411
# batch 1 g_loss : 1.641796
# batch 2 d_loss : 0.258866
# batch 2 g_loss : 1.634727
# Epoch is 71
# Number of batches 3
# batch 0 d_loss : 0.361419
# batch 0 g_loss : 1.431924
# batch 1 d_loss : 0.375623
# batch 1 g_loss : 1.540008
# batch 2 d_loss : 0.249011
# batch 2 g_loss : 1.931394
# Epoch is 72
# Number of batches 3
# batch 0 d_loss : 0.439773
# batch 0 g_loss : 1.949653
# batch 1 d_loss : 0.336486
# batch 1 g_loss : 1.757210
# batch 2 d_loss : 0.313411
# batch 2 g_loss : 2.055756
# Epoch is 73
# Number of batches 3
# batch 0 d_loss : 0.394213
# batch 0 g_loss : 1.758777
# batch 1 d_loss : 0.343695
# batch 1 g_loss : 1.628840
# batch 2 d_loss : 0.201738
# batch 2 g_loss : 1.337278
# Epoch is 74
# Number of batches 3
# batch 0 d_loss : 0.369429
# batch 0 g_loss : 1.241059
# batch 1 d_loss : 0.277633
# batch 1 g_loss : 1.463959
# batch 2 d_loss : 0.271219
# batch 2 g_loss : 1.768607
# Epoch is 75
# Number of batches 3
# batch 0 d_loss : 0.334914
# batch 0 g_loss : 1.929148
# batch 1 d_loss : 0.294012
# batch 1 g_loss : 1.560701
# batch 2 d_loss : 0.288955
# batch 2 g_loss : 1.468747
# Epoch is 76
# Number of batches 3
# batch 0 d_loss : 0.344384
# batch 0 g_loss : 1.353810
# batch 1 d_loss : 0.309931
# batch 1 g_loss : 1.386097
# batch 2 d_loss : 0.224875
# batch 2 g_loss : 1.401732
# Epoch is 77
# Number of batches 3
# batch 0 d_loss : 0.366717
# batch 0 g_loss : 1.471679
# batch 1 d_loss : 0.277435
# batch 1 g_loss : 1.126522
# batch 2 d_loss : 0.319232
# batch 2 g_loss : 1.954685
# Epoch is 78
# Number of batches 3
# batch 0 d_loss : 0.369319
# batch 0 g_loss : 1.867204
# batch 1 d_loss : 0.314057
# batch 1 g_loss : 1.209335
# batch 2 d_loss : 0.283888
# batch 2 g_loss : 1.456331
# Epoch is 79
# Number of batches 3
# batch 0 d_loss : 0.387517
# batch 0 g_loss : 1.503460
# batch 1 d_loss : 0.420871
# batch 1 g_loss : 1.762575
# batch 2 d_loss : 0.297957
# batch 2 g_loss : 1.737265
# Epoch is 80
# Number of batches 3
# batch 0 d_loss : 0.380755
# batch 0 g_loss : 1.255440
# batch 1 d_loss : 0.319754
# batch 1 g_loss : 1.379484
# batch 2 d_loss : 0.218386
# batch 2 g_loss : 1.201815
# Epoch is 81
# Number of batches 3
# batch 0 d_loss : 0.307925
# batch 0 g_loss : 1.576589
# batch 1 d_loss : 0.323414
# batch 1 g_loss : 1.398413
# batch 2 d_loss : 0.298856
# batch 2 g_loss : 1.228206
# Epoch is 82
# Number of batches 3
# batch 0 d_loss : 0.435531
# batch 0 g_loss : 1.893848
# batch 1 d_loss : 0.391411
# batch 1 g_loss : 1.531532
# batch 2 d_loss : 0.308126
# batch 2 g_loss : 1.899619
# Epoch is 83
# Number of batches 3
# batch 0 d_loss : 0.445971
# batch 0 g_loss : 1.408710
# batch 1 d_loss : 0.335969
# batch 1 g_loss : 1.261003
# batch 2 d_loss : 0.318470
# batch 2 g_loss : 1.551491
# Epoch is 84
# Number of batches 3
# batch 0 d_loss : 0.372299
# batch 0 g_loss : 1.496216
# batch 1 d_loss : 0.322250
# batch 1 g_loss : 0.958530
# batch 2 d_loss : 0.270643
# batch 2 g_loss : 1.082752
# Epoch is 85
# Number of batches 3
# batch 0 d_loss : 0.386902
# batch 0 g_loss : 1.136362
# batch 1 d_loss : 0.249030
# batch 1 g_loss : 0.973035
# batch 2 d_loss : 0.324048
# batch 2 g_loss : 1.127102
# Epoch is 86
# Number of batches 3
# batch 0 d_loss : 0.368523
# batch 0 g_loss : 1.409295
# batch 1 d_loss : 0.399997
# batch 1 g_loss : 1.246062
# batch 2 d_loss : 0.389673
# batch 2 g_loss : 2.052467
# Epoch is 87
# Number of batches 3
# batch 0 d_loss : 0.435611
# batch 0 g_loss : 1.723658
# batch 1 d_loss : 0.385740
# batch 1 g_loss : 1.114350
# batch 2 d_loss : 0.234017
# batch 2 g_loss : 1.458430
# Epoch is 88
# Number of batches 3
# batch 0 d_loss : 0.498082
# batch 0 g_loss : 1.372455
# batch 1 d_loss : 0.304201
# batch 1 g_loss : 1.326246
# batch 2 d_loss : 0.312027
# batch 2 g_loss : 1.504186
# Epoch is 89
# Number of batches 3
# batch 0 d_loss : 0.442695
# batch 0 g_loss : 1.412289
# batch 1 d_loss : 0.380892
# batch 1 g_loss : 1.101666
# batch 2 d_loss : 0.296411
# batch 2 g_loss : 1.404910
# Epoch is 90
# Number of batches 3
# batch 0 d_loss : 0.442839
# batch 0 g_loss : 1.243286
# batch 1 d_loss : 0.518128
# batch 1 g_loss : 1.719747
# batch 2 d_loss : 0.252733
# batch 2 g_loss : 1.483126
# Epoch is 91
# Number of batches 3
# batch 0 d_loss : 0.452295
# batch 0 g_loss : 1.393437
# batch 1 d_loss : 0.440264
# batch 1 g_loss : 1.334391
# batch 2 d_loss : 0.334496
# batch 2 g_loss : 1.871965
# Epoch is 92
# Number of batches 3
# batch 0 d_loss : 0.495552
# batch 0 g_loss : 1.442261
# batch 1 d_loss : 0.367553
# batch 1 g_loss : 1.255626
# batch 2 d_loss : 0.428624
# batch 2 g_loss : 1.546036
# Epoch is 93
# Number of batches 3
# batch 0 d_loss : 0.531099
# batch 0 g_loss : 1.425013
# batch 1 d_loss : 0.388929
# batch 1 g_loss : 1.570770
# batch 2 d_loss : 0.518022
# batch 2 g_loss : 2.272449
# Epoch is 94
# Number of batches 3
# batch 0 d_loss : 0.518985
# batch 0 g_loss : 1.560192
# batch 1 d_loss : 0.435139
# batch 1 g_loss : 0.966312
# batch 2 d_loss : 0.359797
# batch 2 g_loss : 1.353894
# Epoch is 95
# Number of batches 3
# batch 0 d_loss : 0.445773
# batch 0 g_loss : 1.498105
# batch 1 d_loss : 0.477542
# batch 1 g_loss : 1.685516
# batch 2 d_loss : 0.329732
# batch 2 g_loss : 1.498578
# Epoch is 96
# Number of batches 3
# batch 0 d_loss : 0.502368
# batch 0 g_loss : 1.467465
# batch 1 d_loss : 0.369220
# batch 1 g_loss : 1.304024
# batch 2 d_loss : 0.494870
# batch 2 g_loss : 1.671788
# Epoch is 97
# Number of batches 3
# batch 0 d_loss : 0.440132
# batch 0 g_loss : 1.649608
# batch 1 d_loss : 0.411664
# batch 1 g_loss : 1.522200
# batch 2 d_loss : 0.484749
# batch 2 g_loss : 1.603300
# Epoch is 98
# Number of batches 3
# batch 0 d_loss : 0.535371
# batch 0 g_loss : 2.061921
# batch 1 d_loss : 0.397921
# batch 1 g_loss : 1.507758
# batch 2 d_loss : 0.460272
# batch 2 g_loss : 1.989944
# Epoch is 99
# Number of batches 3
# batch 0 d_loss : 0.495595
# batch 0 g_loss : 1.400790
# batch 1 d_loss : 0.329246
# batch 1 g_loss : 1.294077
# batch 2 d_loss : 0.364749
# batch 2 g_loss : 1.524580
# Epoch is 100
# Number of batches 3
# batch 0 d_loss : 0.422201
# batch 0 g_loss : 1.468034
# batch 1 d_loss : 0.410984
# batch 1 g_loss : 1.685541
# batch 2 d_loss : 0.377881
# batch 2 g_loss : 1.760328
# Epoch is 101
# Number of batches 3
# batch 0 d_loss : 0.526407
# batch 0 g_loss : 1.633205
# batch 1 d_loss : 0.412590
# batch 1 g_loss : 1.401990
# batch 2 d_loss : 0.419588
# batch 2 g_loss : 1.665985
# Epoch is 102
# Number of batches 3
# batch 0 d_loss : 0.499745
# batch 0 g_loss : 1.374082
# batch 1 d_loss : 0.366229
# batch 1 g_loss : 1.882261
# batch 2 d_loss : 0.364279
# batch 2 g_loss : 1.432451
# Epoch is 103
# Number of batches 3
# batch 0 d_loss : 0.577746
# batch 0 g_loss : 1.618052
# batch 1 d_loss : 0.305674
# batch 1 g_loss : 1.573997
# batch 2 d_loss : 0.429716
# batch 2 g_loss : 1.601413
# Epoch is 104
# Number of batches 3
# batch 0 d_loss : 0.501375
# batch 0 g_loss : 1.424471
# batch 1 d_loss : 0.385810
# batch 1 g_loss : 1.399132
# batch 2 d_loss : 0.446730
# batch 2 g_loss : 1.449041
# Epoch is 105
# Number of batches 3
# batch 0 d_loss : 0.538351
# batch 0 g_loss : 1.308858
# batch 1 d_loss : 0.483403
# batch 1 g_loss : 1.643114
# batch 2 d_loss : 0.275481
# batch 2 g_loss : 1.193320
# Epoch is 106
# Number of batches 3
# batch 0 d_loss : 0.502538
# batch 0 g_loss : 1.915092
# batch 1 d_loss : 0.477860
# batch 1 g_loss : 1.646312
# batch 2 d_loss : 0.270626
# batch 2 g_loss : 1.268955
# Epoch is 107
# Number of batches 3
# batch 0 d_loss : 0.544960
# batch 0 g_loss : 1.548827
# batch 1 d_loss : 0.311215
# batch 1 g_loss : 1.543733
# batch 2 d_loss : 0.379123
# batch 2 g_loss : 1.980828
# Epoch is 108
# Number of batches 3
# batch 0 d_loss : 0.634649
# batch 0 g_loss : 1.512488
# batch 1 d_loss : 0.359035
# batch 1 g_loss : 1.580771
# batch 2 d_loss : 0.359417
# batch 2 g_loss : 2.027812
# Epoch is 109
# Number of batches 3
# batch 0 d_loss : 0.472561
# batch 0 g_loss : 1.505627
# batch 1 d_loss : 0.495052
# batch 1 g_loss : 1.989837
# batch 2 d_loss : 0.322359
# batch 2 g_loss : 1.180971
# Epoch is 110
# Number of batches 3
# batch 0 d_loss : 0.563923
# batch 0 g_loss : 1.448758
# batch 1 d_loss : 0.503902
# batch 1 g_loss : 1.956466
# batch 2 d_loss : 0.279518
# batch 2 g_loss : 1.625345
# Epoch is 111
# Number of batches 3
# batch 0 d_loss : 0.595839
# batch 0 g_loss : 1.471080
# batch 1 d_loss : 0.396075
# batch 1 g_loss : 1.583363
# batch 2 d_loss : 0.343031
# batch 2 g_loss : 1.966214
# Epoch is 112
# Number of batches 3
# batch 0 d_loss : 0.604980
# batch 0 g_loss : 1.672768
# batch 1 d_loss : 0.278158
# batch 1 g_loss : 1.294004
# batch 2 d_loss : 0.303316
# batch 2 g_loss : 1.569289
# Epoch is 113
# Number of batches 3
# batch 0 d_loss : 0.652590
# batch 0 g_loss : 1.597030
# batch 1 d_loss : 0.387545
# batch 1 g_loss : 1.501805
# batch 2 d_loss : 0.292258
# batch 2 g_loss : 1.702760
# Epoch is 114
# Number of batches 3
# batch 0 d_loss : 0.530530
# batch 0 g_loss : 1.369747
# batch 1 d_loss : 0.398050
# batch 1 g_loss : 1.647466
# batch 2 d_loss : 0.355748
# batch 2 g_loss : 1.577073
# Epoch is 115
# Number of batches 3
# batch 0 d_loss : 0.536823
# batch 0 g_loss : 1.471297
# batch 1 d_loss : 0.399384
# batch 1 g_loss : 1.333829
# batch 2 d_loss : 0.333388
# batch 2 g_loss : 1.472505
# Epoch is 116
# Number of batches 3
# batch 0 d_loss : 0.496339
# batch 0 g_loss : 1.973874
# batch 1 d_loss : 0.444833
# batch 1 g_loss : 1.033018
# batch 2 d_loss : 0.334305
# batch 2 g_loss : 1.888516
# Epoch is 117
# Number of batches 3
# batch 0 d_loss : 0.605355
# batch 0 g_loss : 2.130679
# batch 1 d_loss : 0.371269
# batch 1 g_loss : 1.877581
# batch 2 d_loss : 0.285812
# batch 2 g_loss : 1.548223
# Epoch is 118
# Number of batches 3
# batch 0 d_loss : 0.448285
# batch 0 g_loss : 1.059974
# batch 1 d_loss : 0.408277
# batch 1 g_loss : 1.310282
# batch 2 d_loss : 0.321329
# batch 2 g_loss : 1.697254
# Epoch is 119
# Number of batches 3
# batch 0 d_loss : 0.576019
# batch 0 g_loss : 1.462480
# batch 1 d_loss : 0.330316
# batch 1 g_loss : 1.108557
# batch 2 d_loss : 0.387666
# batch 2 g_loss : 1.888563
# Epoch is 120
# Number of batches 3
# batch 0 d_loss : 0.563836
# batch 0 g_loss : 1.808228
# batch 1 d_loss : 0.393243
# batch 1 g_loss : 1.602685
# batch 2 d_loss : 0.376340
# batch 2 g_loss : 1.716797
# Epoch is 121
# Number of batches 3
# batch 0 d_loss : 0.549651
# batch 0 g_loss : 1.603870
# batch 1 d_loss : 0.418841
# batch 1 g_loss : 1.729945
# batch 2 d_loss : 0.297375
# batch 2 g_loss : 1.861155
# Epoch is 122
# Number of batches 3
# batch 0 d_loss : 0.530774
# batch 0 g_loss : 1.675161
# batch 1 d_loss : 0.283049
# batch 1 g_loss : 1.188946
# batch 2 d_loss : 0.299656
# batch 2 g_loss : 1.616217
# Epoch is 123
# Number of batches 3
# batch 0 d_loss : 0.673388
# batch 0 g_loss : 2.116171
# batch 1 d_loss : 0.349201
# batch 1 g_loss : 1.437999
# batch 2 d_loss : 0.347213
# batch 2 g_loss : 1.581305
# Epoch is 124
# Number of batches 3
# batch 0 d_loss : 0.550623
# batch 0 g_loss : 1.622595
# batch 1 d_loss : 0.391927
# batch 1 g_loss : 1.462239
# batch 2 d_loss : 0.395186
# batch 2 g_loss : 1.586755
# Epoch is 125
# Number of batches 3
# batch 0 d_loss : 0.507231
# batch 0 g_loss : 1.776604
# batch 1 d_loss : 0.340905
# batch 1 g_loss : 1.547713
# batch 2 d_loss : 0.320463
# batch 2 g_loss : 1.583537
# Epoch is 126
# Number of batches 3
# batch 0 d_loss : 0.507680
# batch 0 g_loss : 1.308969
# batch 1 d_loss : 0.464655
# batch 1 g_loss : 1.778022
# batch 2 d_loss : 0.393568
# batch 2 g_loss : 1.826750
# Epoch is 127
# Number of batches 3
# batch 0 d_loss : 0.635502
# batch 0 g_loss : 1.717454
# batch 1 d_loss : 0.416239
# batch 1 g_loss : 1.478224
# batch 2 d_loss : 0.427576
# batch 2 g_loss : 1.352263
# Epoch is 128
# Number of batches 3
# batch 0 d_loss : 0.498634
# batch 0 g_loss : 1.234002
# batch 1 d_loss : 0.368124
# batch 1 g_loss : 1.342821
# batch 2 d_loss : 0.340273
# batch 2 g_loss : 1.443880
# Epoch is 129
# Number of batches 3
# batch 0 d_loss : 0.666382
# batch 0 g_loss : 2.207717
# batch 1 d_loss : 0.337480
# batch 1 g_loss : 1.284710
# batch 2 d_loss : 0.365258
# batch 2 g_loss : 1.707171
# Epoch is 130
# Number of batches 3
# batch 0 d_loss : 0.599315
# batch 0 g_loss : 1.711180
# batch 1 d_loss : 0.329220
# batch 1 g_loss : 1.444130
# batch 2 d_loss : 0.362327
# batch 2 g_loss : 1.683112
# Epoch is 131
# Number of batches 3
# batch 0 d_loss : 0.448266
# batch 0 g_loss : 1.797168
# batch 1 d_loss : 0.399964
# batch 1 g_loss : 1.504351
# batch 2 d_loss : 0.439951
# batch 2 g_loss : 1.636867
# Epoch is 132
# Number of batches 3
# batch 0 d_loss : 0.464835
# batch 0 g_loss : 1.341162
# batch 1 d_loss : 0.367316
# batch 1 g_loss : 1.432605
# batch 2 d_loss : 0.419761
# batch 2 g_loss : 1.391666
# Epoch is 133
# Number of batches 3
# batch 0 d_loss : 0.500573
# batch 0 g_loss : 1.415877
# batch 1 d_loss : 0.426995
# batch 1 g_loss : 1.832361
# batch 2 d_loss : 0.417741
# batch 2 g_loss : 2.029314
# Epoch is 134
# Number of batches 3
# batch 0 d_loss : 0.425041
# batch 0 g_loss : 1.315450
# batch 1 d_loss : 0.386414
# batch 1 g_loss : 1.329312
# batch 2 d_loss : 0.311553
# batch 2 g_loss : 1.214743
# Epoch is 135
# Number of batches 3
# batch 0 d_loss : 0.440506
# batch 0 g_loss : 1.188107
# batch 1 d_loss : 0.426065
# batch 1 g_loss : 1.494086
# batch 2 d_loss : 0.354539
# batch 2 g_loss : 1.581317
# Epoch is 136
# Number of batches 3
# batch 0 d_loss : 0.478085
# batch 0 g_loss : 1.192671
# batch 1 d_loss : 0.543788
# batch 1 g_loss : 1.652492
# batch 2 d_loss : 0.354355
# batch 2 g_loss : 2.311994
# Epoch is 137
# Number of batches 3
# batch 0 d_loss : 0.446664
# batch 0 g_loss : 1.200148
# batch 1 d_loss : 0.454595
# batch 1 g_loss : 1.765772
# batch 2 d_loss : 0.338111
# batch 2 g_loss : 1.589096
# Epoch is 138
# Number of batches 3
# batch 0 d_loss : 0.444950
# batch 0 g_loss : 1.509792
# batch 1 d_loss : 0.420108
# batch 1 g_loss : 1.640237
# batch 2 d_loss : 0.280712
# batch 2 g_loss : 1.510720
# Epoch is 139
# Number of batches 3
# batch 0 d_loss : 0.556154
# batch 0 g_loss : 1.727389
# batch 1 d_loss : 0.354975
# batch 1 g_loss : 1.396983
# batch 2 d_loss : 0.279242
# batch 2 g_loss : 1.404605
# Epoch is 140
# Number of batches 3
# batch 0 d_loss : 0.489322
# batch 0 g_loss : 1.550471
# batch 1 d_loss : 0.497621
# batch 1 g_loss : 1.695972
# batch 2 d_loss : 0.362301
# batch 2 g_loss : 1.678554
# Epoch is 141
# Number of batches 3
# batch 0 d_loss : 0.580095
# batch 0 g_loss : 1.904930
# batch 1 d_loss : 0.415766
# batch 1 g_loss : 1.670689
# batch 2 d_loss : 0.349355
# batch 2 g_loss : 1.500168
# Epoch is 142
# Number of batches 3
# batch 0 d_loss : 0.525455
# batch 0 g_loss : 1.466032
# batch 1 d_loss : 0.456048
# batch 1 g_loss : 1.518464
# batch 2 d_loss : 0.351429
# batch 2 g_loss : 1.490775
# Epoch is 143
# Number of batches 3
# batch 0 d_loss : 0.496926
# batch 0 g_loss : 1.245351
# batch 1 d_loss : 0.385413
# batch 1 g_loss : 1.784006
# batch 2 d_loss : 0.361485
# batch 2 g_loss : 1.767993
# Epoch is 144
# Number of batches 3
# batch 0 d_loss : 0.558778
# batch 0 g_loss : 1.799871
# batch 1 d_loss : 0.337899
# batch 1 g_loss : 1.219731
# batch 2 d_loss : 0.426526
# batch 2 g_loss : 1.582113
# Epoch is 145
# Number of batches 3
# batch 0 d_loss : 0.553710
# batch 0 g_loss : 1.740379
# batch 1 d_loss : 0.401598
# batch 1 g_loss : 1.606370
# batch 2 d_loss : 0.345485
# batch 2 g_loss : 1.374107
# Epoch is 146
# Number of batches 3
# batch 0 d_loss : 0.633779
# batch 0 g_loss : 1.405393
# batch 1 d_loss : 0.401859
# batch 1 g_loss : 1.532688
# batch 2 d_loss : 0.413372
# batch 2 g_loss : 1.944014
# Epoch is 147
# Number of batches 3
# batch 0 d_loss : 0.477013
# batch 0 g_loss : 1.193836
# batch 1 d_loss : 0.357313
# batch 1 g_loss : 1.172134
# batch 2 d_loss : 0.300636
# batch 2 g_loss : 1.674204
# Epoch is 148
# Number of batches 3
# batch 0 d_loss : 0.549013
# batch 0 g_loss : 1.189850
# batch 1 d_loss : 0.498917
# batch 1 g_loss : 1.418566
# batch 2 d_loss : 0.402121
# batch 2 g_loss : 1.355668
# Epoch is 149
# Number of batches 3
# batch 0 d_loss : 0.570009
# batch 0 g_loss : 1.574155
# batch 1 d_loss : 0.311234
# batch 1 g_loss : 1.228907
# batch 2 d_loss : 0.389390
# batch 2 g_loss : 1.387862
# Epoch is 150
# Number of batches 3
# batch 0 d_loss : 0.674358
# batch 0 g_loss : 1.747885
# batch 1 d_loss : 0.457975
# batch 1 g_loss : 1.705735
# batch 2 d_loss : 0.319040
# batch 2 g_loss : 1.762882
# Epoch is 151
# Number of batches 3
# batch 0 d_loss : 0.560068
# batch 0 g_loss : 1.273395
# batch 1 d_loss : 0.451287
# batch 1 g_loss : 1.391543
# batch 2 d_loss : 0.347145
# batch 2 g_loss : 1.403706
# Epoch is 152
# Number of batches 3
# batch 0 d_loss : 0.497082
# batch 0 g_loss : 1.287625
# batch 1 d_loss : 0.336927
# batch 1 g_loss : 1.237626
# batch 2 d_loss : 0.252373
# batch 2 g_loss : 1.413425
# Epoch is 153
# Number of batches 3
# batch 0 d_loss : 0.480643
# batch 0 g_loss : 1.505213
# batch 1 d_loss : 0.329336
# batch 1 g_loss : 1.480082
# batch 2 d_loss : 0.370179
# batch 2 g_loss : 1.603464
# Epoch is 154
# Number of batches 3
# batch 0 d_loss : 0.518567
# batch 0 g_loss : 1.556970
# batch 1 d_loss : 0.372225
# batch 1 g_loss : 1.551478
# batch 2 d_loss : 0.398284
# batch 2 g_loss : 1.841683
# Epoch is 155
# Number of batches 3
# batch 0 d_loss : 0.583056
# batch 0 g_loss : 1.816271
# batch 1 d_loss : 0.400441
# batch 1 g_loss : 1.554651
# batch 2 d_loss : 0.350043
# batch 2 g_loss : 1.556612
# Epoch is 156
# Number of batches 3
# batch 0 d_loss : 0.478598
# batch 0 g_loss : 1.074741
# batch 1 d_loss : 0.370694
# batch 1 g_loss : 1.793715
# batch 2 d_loss : 0.337916
# batch 2 g_loss : 1.545334
# Epoch is 157
# Number of batches 3
# batch 0 d_loss : 0.542413
# batch 0 g_loss : 1.303930
# batch 1 d_loss : 0.371232
# batch 1 g_loss : 1.221505
# batch 2 d_loss : 0.347080
# batch 2 g_loss : 1.795613
# Epoch is 158
# Number of batches 3
# batch 0 d_loss : 0.551492
# batch 0 g_loss : 1.522878
# batch 1 d_loss : 0.455272
# batch 1 g_loss : 2.094065
# batch 2 d_loss : 0.305612
# batch 2 g_loss : 1.527848
# Epoch is 159
# Number of batches 3
# batch 0 d_loss : 0.606562
# batch 0 g_loss : 1.592211
# batch 1 d_loss : 0.359336
# batch 1 g_loss : 1.208174
# batch 2 d_loss : 0.366610
# batch 2 g_loss : 1.572559
# Epoch is 160
# Number of batches 3
# batch 0 d_loss : 0.506205
# batch 0 g_loss : 1.817119
# batch 1 d_loss : 0.277876
# batch 1 g_loss : 1.100003
# batch 2 d_loss : 0.302134
# batch 2 g_loss : 1.622486
# Epoch is 161
# Number of batches 3
# batch 0 d_loss : 0.512131
# batch 0 g_loss : 1.701567
# batch 1 d_loss : 0.373101
# batch 1 g_loss : 1.221374
# batch 2 d_loss : 0.323387
# batch 2 g_loss : 1.675011
# Epoch is 162
# Number of batches 3
# batch 0 d_loss : 0.420559
# batch 0 g_loss : 0.997383
# batch 1 d_loss : 0.326623
# batch 1 g_loss : 1.453567
# batch 2 d_loss : 0.317900
# batch 2 g_loss : 1.592820
# Epoch is 163
# Number of batches 3
# batch 0 d_loss : 0.528541
# batch 0 g_loss : 1.660267
# batch 1 d_loss : 0.497555
# batch 1 g_loss : 1.740975
# batch 2 d_loss : 0.280345
# batch 2 g_loss : 1.188665
# Epoch is 164
# Number of batches 3
# batch 0 d_loss : 0.505013
# batch 0 g_loss : 1.256052
# batch 1 d_loss : 0.322286
# batch 1 g_loss : 1.359243
# batch 2 d_loss : 0.354655
# batch 2 g_loss : 1.901665
# Epoch is 165
# Number of batches 3
# batch 0 d_loss : 0.550665
# batch 0 g_loss : 1.583184
# batch 1 d_loss : 0.462906
# batch 1 g_loss : 1.722418
# batch 2 d_loss : 0.324717
# batch 2 g_loss : 1.373272
# Epoch is 166
# Number of batches 3
# batch 0 d_loss : 0.587491
# batch 0 g_loss : 1.506832
# batch 1 d_loss : 0.422291
# batch 1 g_loss : 1.570784
# batch 2 d_loss : 0.239916
# batch 2 g_loss : 1.108125
# Epoch is 167
# Number of batches 3
# batch 0 d_loss : 0.520242
# batch 0 g_loss : 1.725925
# batch 1 d_loss : 0.318612
# batch 1 g_loss : 1.161748
# batch 2 d_loss : 0.434959
# batch 2 g_loss : 2.102428
# Epoch is 168
# Number of batches 3
# batch 0 d_loss : 0.474645
# batch 0 g_loss : 1.405290
# batch 1 d_loss : 0.443354
# batch 1 g_loss : 1.580799
# batch 2 d_loss : 0.376935
# batch 2 g_loss : 1.831459
# Epoch is 169
# Number of batches 3
# batch 0 d_loss : 0.428419
# batch 0 g_loss : 1.812024
# batch 1 d_loss : 0.477035
# batch 1 g_loss : 1.556024
# batch 2 d_loss : 0.515675
# batch 2 g_loss : 2.182536
# Epoch is 170
# Number of batches 3
# batch 0 d_loss : 0.506159
# batch 0 g_loss : 1.326628
# batch 1 d_loss : 0.468056
# batch 1 g_loss : 1.524538
# batch 2 d_loss : 0.313020
# batch 2 g_loss : 1.456821
# Epoch is 171
# Number of batches 3
# batch 0 d_loss : 0.659668
# batch 0 g_loss : 1.778118
# batch 1 d_loss : 0.451468
# batch 1 g_loss : 1.477414
# batch 2 d_loss : 0.340520
# batch 2 g_loss : 1.516682
# Epoch is 172
# Number of batches 3
# batch 0 d_loss : 0.451095
# batch 0 g_loss : 1.010359
# batch 1 d_loss : 0.352542
# batch 1 g_loss : 1.526279
# batch 2 d_loss : 0.342327
# batch 2 g_loss : 1.462376
# Epoch is 173
# Number of batches 3
# batch 0 d_loss : 0.445012
# batch 0 g_loss : 1.476749
# batch 1 d_loss : 0.365525
# batch 1 g_loss : 1.489685
# batch 2 d_loss : 0.414550
# batch 2 g_loss : 1.745816
# Epoch is 174
# Number of batches 3
# batch 0 d_loss : 0.479141
# batch 0 g_loss : 1.412360
# batch 1 d_loss : 0.422971
# batch 1 g_loss : 1.609779
# batch 2 d_loss : 0.411891
# batch 2 g_loss : 1.514108
# Epoch is 175
# Number of batches 3
# batch 0 d_loss : 0.504290
# batch 0 g_loss : 1.278908
# batch 1 d_loss : 0.333151
# batch 1 g_loss : 1.815455
# batch 2 d_loss : 0.393300
# batch 2 g_loss : 1.431473
# Epoch is 176
# Number of batches 3
# batch 0 d_loss : 0.495068
# batch 0 g_loss : 1.711792
# batch 1 d_loss : 0.363378
# batch 1 g_loss : 1.761618
# batch 2 d_loss : 0.337715
# batch 2 g_loss : 1.963056
# Epoch is 177
# Number of batches 3
# batch 0 d_loss : 0.485845
# batch 0 g_loss : 1.517422
# batch 1 d_loss : 0.364736
# batch 1 g_loss : 1.109735
# batch 2 d_loss : 0.301298
# batch 2 g_loss : 1.638964
# Epoch is 178
# Number of batches 3
# batch 0 d_loss : 0.417765
# batch 0 g_loss : 1.322160
# batch 1 d_loss : 0.407523
# batch 1 g_loss : 1.685138
# batch 2 d_loss : 0.454608
# batch 2 g_loss : 2.337549
# Epoch is 179
# Number of batches 3
# batch 0 d_loss : 0.492906
# batch 0 g_loss : 1.500753
# batch 1 d_loss : 0.338823
# batch 1 g_loss : 1.527783
# batch 2 d_loss : 0.387962
# batch 2 g_loss : 1.771045
# Epoch is 180
# Number of batches 3
# batch 0 d_loss : 0.507038
# batch 0 g_loss : 1.310737
# batch 1 d_loss : 0.348028
# batch 1 g_loss : 1.538423
# batch 2 d_loss : 0.278020
# batch 2 g_loss : 1.264744
# Epoch is 181
# Number of batches 3
# batch 0 d_loss : 0.330125
# batch 0 g_loss : 0.771779
# batch 1 d_loss : 0.473776
# batch 1 g_loss : 1.611576
# batch 2 d_loss : 0.297513
# batch 2 g_loss : 1.446340
# Epoch is 182
# Number of batches 3
# batch 0 d_loss : 0.459046
# batch 0 g_loss : 1.535875
# batch 1 d_loss : 0.370675
# batch 1 g_loss : 1.523277
# batch 2 d_loss : 0.512863
# batch 2 g_loss : 2.128699
# Epoch is 183
# Number of batches 3
# batch 0 d_loss : 0.497661
# batch 0 g_loss : 1.511409
# batch 1 d_loss : 0.335203
# batch 1 g_loss : 1.445165
# batch 2 d_loss : 0.455771
# batch 2 g_loss : 1.946303
# Epoch is 184
# Number of batches 3
# batch 0 d_loss : 0.466079
# batch 0 g_loss : 1.616368
# batch 1 d_loss : 0.378128
# batch 1 g_loss : 1.333745
# batch 2 d_loss : 0.343502
# batch 2 g_loss : 1.734272
# Epoch is 185
# Number of batches 3
# batch 0 d_loss : 0.386640
# batch 0 g_loss : 1.297287
# batch 1 d_loss : 0.329787
# batch 1 g_loss : 1.171917
# batch 2 d_loss : 0.343747
# batch 2 g_loss : 1.891755
# Epoch is 186
# Number of batches 3
# batch 0 d_loss : 0.540510
# batch 0 g_loss : 1.841264
# batch 1 d_loss : 0.455158
# batch 1 g_loss : 1.483133
# batch 2 d_loss : 0.349246
# batch 2 g_loss : 1.532172
# Epoch is 187
# Number of batches 3
# batch 0 d_loss : 0.497112
# batch 0 g_loss : 2.059879
# batch 1 d_loss : 0.424510
# batch 1 g_loss : 1.420244
# batch 2 d_loss : 0.418983
# batch 2 g_loss : 1.444819
# Epoch is 188
# Number of batches 3
# batch 0 d_loss : 0.435052
# batch 0 g_loss : 1.325294
# batch 1 d_loss : 0.330574
# batch 1 g_loss : 1.081311
# batch 2 d_loss : 0.409078
# batch 2 g_loss : 1.588883
# Epoch is 189
# Number of batches 3
# batch 0 d_loss : 0.423780
# batch 0 g_loss : 1.602252
# batch 1 d_loss : 0.406450
# batch 1 g_loss : 1.448585
# batch 2 d_loss : 0.362526
# batch 2 g_loss : 1.847328
# Epoch is 190
# Number of batches 3
# batch 0 d_loss : 0.433978
# batch 0 g_loss : 1.711023
# batch 1 d_loss : 0.383509
# batch 1 g_loss : 1.488432
# batch 2 d_loss : 0.336507
# batch 2 g_loss : 1.528774
# Epoch is 191
# Number of batches 3
# batch 0 d_loss : 0.358185
# batch 0 g_loss : 0.882189
# batch 1 d_loss : 0.372088
# batch 1 g_loss : 1.448636
# batch 2 d_loss : 0.361614
# batch 2 g_loss : 2.092161
# Epoch is 192
# Number of batches 3
# batch 0 d_loss : 0.400946
# batch 0 g_loss : 1.632651
# batch 1 d_loss : 0.358067
# batch 1 g_loss : 1.367677
# batch 2 d_loss : 0.330874
# batch 2 g_loss : 1.532539
# Epoch is 193
# Number of batches 3
# batch 0 d_loss : 0.436187
# batch 0 g_loss : 1.717380
# batch 1 d_loss : 0.400634
# batch 1 g_loss : 1.436295
# batch 2 d_loss : 0.343666
# batch 2 g_loss : 1.681141
# Epoch is 194
# Number of batches 3
# batch 0 d_loss : 0.441435
# batch 0 g_loss : 1.925996
# batch 1 d_loss : 0.358543
# batch 1 g_loss : 0.813491
# batch 2 d_loss : 0.459690
# batch 2 g_loss : 1.899881
# Epoch is 195
# Number of batches 3
# batch 0 d_loss : 0.430447
# batch 0 g_loss : 1.488471
# batch 1 d_loss : 0.335608
# batch 1 g_loss : 1.268612
# batch 2 d_loss : 0.353702
# batch 2 g_loss : 1.570607
# Epoch is 196
# Number of batches 3
# batch 0 d_loss : 0.432755
# batch 0 g_loss : 1.316631
# batch 1 d_loss : 0.357334
# batch 1 g_loss : 1.412959
# batch 2 d_loss : 0.318871
# batch 2 g_loss : 1.480987
# Epoch is 197
# Number of batches 3
# batch 0 d_loss : 0.426156
# batch 0 g_loss : 1.867532
# batch 1 d_loss : 0.328352
# batch 1 g_loss : 1.458045
# batch 2 d_loss : 0.509516
# batch 2 g_loss : 1.955262
# Epoch is 198
# Number of batches 3
# batch 0 d_loss : 0.441779
# batch 0 g_loss : 1.759588
# batch 1 d_loss : 0.354012
# batch 1 g_loss : 1.327035
# batch 2 d_loss : 0.326441
# batch 2 g_loss : 1.432275
# Epoch is 199
# Number of batches 3
# batch 0 d_loss : 0.309792
# batch 0 g_loss : 1.289955
# batch 1 d_loss : 0.330450
# batch 1 g_loss : 1.739640
# batch 2 d_loss : 0.400633
# batch 2 g_loss : 1.753291
# Epoch is 200
# Number of batches 3
# batch 0 d_loss : 0.391111
# batch 0 g_loss : 1.493626
# batch 1 d_loss : 0.322367
# batch 1 g_loss : 1.730755
# batch 2 d_loss : 0.311358
# batch 2 g_loss : 1.336264
# Epoch is 201
# Number of batches 3
# batch 0 d_loss : 0.426088
# batch 0 g_loss : 1.841294
# batch 1 d_loss : 0.423543
# batch 1 g_loss : 1.644520
# batch 2 d_loss : 0.394850
# batch 2 g_loss : 1.293822
# Epoch is 202
# Number of batches 3
# batch 0 d_loss : 0.346343
# batch 0 g_loss : 1.354621
# batch 1 d_loss : 0.273210
# batch 1 g_loss : 1.334137
# batch 2 d_loss : 0.389446
# batch 2 g_loss : 1.503635
# Epoch is 203
# Number of batches 3
# batch 0 d_loss : 0.346332
# batch 0 g_loss : 1.479571
# batch 1 d_loss : 0.323087
# batch 1 g_loss : 1.790406
# batch 2 d_loss : 0.298336
# batch 2 g_loss : 1.471700
# Epoch is 204
# Number of batches 3
# batch 0 d_loss : 0.426626
# batch 0 g_loss : 1.942769
# batch 1 d_loss : 0.390529
# batch 1 g_loss : 2.005805
# batch 2 d_loss : 0.397237
# batch 2 g_loss : 1.678179
# Epoch is 205
# Number of batches 3
# batch 0 d_loss : 0.315298
# batch 0 g_loss : 1.404236
# batch 1 d_loss : 0.341578
# batch 1 g_loss : 1.547633
# batch 2 d_loss : 0.334125
# batch 2 g_loss : 1.669800
# Epoch is 206
# Number of batches 3
# batch 0 d_loss : 0.300527
# batch 0 g_loss : 1.308894
# batch 1 d_loss : 0.395024
# batch 1 g_loss : 2.225737
# batch 2 d_loss : 0.366298
# batch 2 g_loss : 1.694010
# Epoch is 207
# Number of batches 3
# batch 0 d_loss : 0.383299
# batch 0 g_loss : 1.257113
# batch 1 d_loss : 0.297105
# batch 1 g_loss : 1.727719
# batch 2 d_loss : 0.394986
# batch 2 g_loss : 1.898947
# Epoch is 208
# Number of batches 3
# batch 0 d_loss : 0.398285
# batch 0 g_loss : 1.468901
# batch 1 d_loss : 0.248545
# batch 1 g_loss : 1.207226
# batch 2 d_loss : 0.378337
# batch 2 g_loss : 1.875654
# Epoch is 209
# Number of batches 3
# batch 0 d_loss : 0.358572
# batch 0 g_loss : 1.490476
# batch 1 d_loss : 0.310183
# batch 1 g_loss : 1.934614
# batch 2 d_loss : 0.265548
# batch 2 g_loss : 1.309330
# Epoch is 210
# Number of batches 3
# batch 0 d_loss : 0.318947
# batch 0 g_loss : 1.385716
# batch 1 d_loss : 0.285362
# batch 1 g_loss : 1.526063
# batch 2 d_loss : 0.247418
# batch 2 g_loss : 1.494184
# Epoch is 211
# Number of batches 3
# batch 0 d_loss : 0.375458
# batch 0 g_loss : 1.755713
# batch 1 d_loss : 0.324460
# batch 1 g_loss : 2.064035
# batch 2 d_loss : 0.303927
# batch 2 g_loss : 1.657328
# Epoch is 212
# Number of batches 3
# batch 0 d_loss : 0.452049
# batch 0 g_loss : 2.145629
# batch 1 d_loss : 0.282695
# batch 1 g_loss : 1.253070
# batch 2 d_loss : 0.475208
# batch 2 g_loss : 2.235577
# Epoch is 213
# Number of batches 3
# batch 0 d_loss : 0.469612
# batch 0 g_loss : 1.971269
# batch 1 d_loss : 0.340405
# batch 1 g_loss : 1.180741
# batch 2 d_loss : 0.323121
# batch 2 g_loss : 1.794742
# Epoch is 214
# Number of batches 3
# batch 0 d_loss : 0.289458
# batch 0 g_loss : 1.248014
# batch 1 d_loss : 0.266522
# batch 1 g_loss : 1.566177
# batch 2 d_loss : 0.300153
# batch 2 g_loss : 1.741131
# Epoch is 215
# Number of batches 3
# batch 0 d_loss : 0.414292
# batch 0 g_loss : 2.205740
# batch 1 d_loss : 0.321142
# batch 1 g_loss : 1.273356
# batch 2 d_loss : 0.272820
# batch 2 g_loss : 1.509385
# Epoch is 216
# Number of batches 3
# batch 0 d_loss : 0.406847
# batch 0 g_loss : 2.312132
# batch 1 d_loss : 0.399172
# batch 1 g_loss : 1.763922
# batch 2 d_loss : 0.357889
# batch 2 g_loss : 1.993278
# Epoch is 217
# Number of batches 3
# batch 0 d_loss : 0.385223
# batch 0 g_loss : 1.922712
# batch 1 d_loss : 0.276540
# batch 1 g_loss : 1.581391
# batch 2 d_loss : 0.399693
# batch 2 g_loss : 1.861411
# Epoch is 218
# Number of batches 3
# batch 0 d_loss : 0.359631
# batch 0 g_loss : 1.783044
# batch 1 d_loss : 0.381085
# batch 1 g_loss : 1.843959
# batch 2 d_loss : 0.340400
# batch 2 g_loss : 1.814759
# Epoch is 219
# Number of batches 3
# batch 0 d_loss : 0.349094
# batch 0 g_loss : 1.615283
# batch 1 d_loss : 0.369772
# batch 1 g_loss : 2.185249
# batch 2 d_loss : 0.335329
# batch 2 g_loss : 1.881659
# Epoch is 220
# Number of batches 3
# batch 0 d_loss : 0.485526
# batch 0 g_loss : 1.977354
# batch 1 d_loss : 0.402140
# batch 1 g_loss : 1.717238
# batch 2 d_loss : 0.244332
# batch 2 g_loss : 1.217099
# Epoch is 221
# Number of batches 3
# batch 0 d_loss : 0.404368
# batch 0 g_loss : 1.505465
# batch 1 d_loss : 0.256096
# batch 1 g_loss : 1.099259
# batch 2 d_loss : 0.362511
# batch 2 g_loss : 2.429267
# Epoch is 222
# Number of batches 3
# batch 0 d_loss : 0.355951
# batch 0 g_loss : 1.810130
# batch 1 d_loss : 0.376497
# batch 1 g_loss : 1.951890
# batch 2 d_loss : 0.266267
# batch 2 g_loss : 1.522495
# Epoch is 223
# Number of batches 3
# batch 0 d_loss : 0.305061
# batch 0 g_loss : 1.003043
# batch 1 d_loss : 0.274092
# batch 1 g_loss : 1.722190
# batch 2 d_loss : 0.276893
# batch 2 g_loss : 2.210727
# Epoch is 224
# Number of batches 3
# batch 0 d_loss : 0.458286
# batch 0 g_loss : 2.033621
# batch 1 d_loss : 0.369080
# batch 1 g_loss : 1.918310
# batch 2 d_loss : 0.294727
# batch 2 g_loss : 1.899756
# Epoch is 225
# Number of batches 3
# batch 0 d_loss : 0.326975
# batch 0 g_loss : 1.205792
# batch 1 d_loss : 0.292997
# batch 1 g_loss : 1.305584
# batch 2 d_loss : 0.220028
# batch 2 g_loss : 1.763118
# Epoch is 226
# Number of batches 3
# batch 0 d_loss : 0.272717
# batch 0 g_loss : 1.062564
# batch 1 d_loss : 0.335271
# batch 1 g_loss : 1.690719
# batch 2 d_loss : 0.295525
# batch 2 g_loss : 2.084944
# Epoch is 227
# Number of batches 3
# batch 0 d_loss : 0.335826
# batch 0 g_loss : 1.610928
# batch 1 d_loss : 0.372432
# batch 1 g_loss : 1.881446
# batch 2 d_loss : 0.317859
# batch 2 g_loss : 2.478608
# Epoch is 228
# Number of batches 3
# batch 0 d_loss : 0.351172
# batch 0 g_loss : 1.643394
# batch 1 d_loss : 0.306717
# batch 1 g_loss : 1.449080
# batch 2 d_loss : 0.165821
# batch 2 g_loss : 1.218466
# Epoch is 229
# Number of batches 3
# batch 0 d_loss : 0.392186
# batch 0 g_loss : 1.513657
# batch 1 d_loss : 0.327516
# batch 1 g_loss : 1.500819
# batch 2 d_loss : 0.352410
# batch 2 g_loss : 2.206607
# Epoch is 230
# Number of batches 3
# batch 0 d_loss : 0.357501
# batch 0 g_loss : 1.617744
# batch 1 d_loss : 0.421074
# batch 1 g_loss : 2.033958
# batch 2 d_loss : 0.266524
# batch 2 g_loss : 2.185261
# Epoch is 231
# Number of batches 3
# batch 0 d_loss : 0.270297
# batch 0 g_loss : 1.354943
# batch 1 d_loss : 0.300059
# batch 1 g_loss : 1.629239
# batch 2 d_loss : 0.290945
# batch 2 g_loss : 2.505746
# Epoch is 232
# Number of batches 3
# batch 0 d_loss : 0.369131
# batch 0 g_loss : 2.147503
# batch 1 d_loss : 0.323048
# batch 1 g_loss : 1.270488
# batch 2 d_loss : 0.235628
# batch 2 g_loss : 1.631395
# Epoch is 233
# Number of batches 3
# batch 0 d_loss : 0.318956
# batch 0 g_loss : 1.390562
# batch 1 d_loss : 0.429273
# batch 1 g_loss : 2.075431
# batch 2 d_loss : 0.288022
# batch 2 g_loss : 2.085454
# Epoch is 234
# Number of batches 3
# batch 0 d_loss : 0.243271
# batch 0 g_loss : 1.219642
# batch 1 d_loss : 0.413395
# batch 1 g_loss : 2.226467
# batch 2 d_loss : 0.225035
# batch 2 g_loss : 1.714748
# Epoch is 235
# Number of batches 3
# batch 0 d_loss : 0.283577
# batch 0 g_loss : 1.990501
# batch 1 d_loss : 0.370666
# batch 1 g_loss : 1.797467
# batch 2 d_loss : 0.259882
# batch 2 g_loss : 2.302949
# Epoch is 236
# Number of batches 3
# batch 0 d_loss : 0.256539
# batch 0 g_loss : 1.879808
# batch 1 d_loss : 0.207469
# batch 1 g_loss : 1.208619
# batch 2 d_loss : 0.545890
# batch 2 g_loss : 2.743536
# Epoch is 237
# Number of batches 3
# batch 0 d_loss : 0.355466
# batch 0 g_loss : 2.395444
# batch 1 d_loss : 0.433387
# batch 1 g_loss : 1.463167
# batch 2 d_loss : 0.224961
# batch 2 g_loss : 2.068803
# Epoch is 238
# Number of batches 3
# batch 0 d_loss : 0.236277
# batch 0 g_loss : 1.842907
# batch 1 d_loss : 0.277958
# batch 1 g_loss : 1.938812
# batch 2 d_loss : 0.320891
# batch 2 g_loss : 2.388977
# Epoch is 239
# Number of batches 3
# batch 0 d_loss : 0.268598
# batch 0 g_loss : 2.043559
# batch 1 d_loss : 0.380038
# batch 1 g_loss : 1.711172
# batch 2 d_loss : 0.237564
# batch 2 g_loss : 1.805092
# Epoch is 240
# Number of batches 3
# batch 0 d_loss : 0.270593
# batch 0 g_loss : 1.833447
# batch 1 d_loss : 0.432279
# batch 1 g_loss : 2.344119
# batch 2 d_loss : 0.327658
# batch 2 g_loss : 2.323677
# Epoch is 241
# Number of batches 3
# batch 0 d_loss : 0.244786
# batch 0 g_loss : 1.893242
# batch 1 d_loss : 0.290546
# batch 1 g_loss : 1.360778
# batch 2 d_loss : 0.215540
# batch 2 g_loss : 1.603679
# Epoch is 242
# Number of batches 3
# batch 0 d_loss : 0.224142
# batch 0 g_loss : 1.552907
# batch 1 d_loss : 0.265479
# batch 1 g_loss : 1.529811
# batch 2 d_loss : 0.252436
# batch 2 g_loss : 1.863127
# Epoch is 243
# Number of batches 3
# batch 0 d_loss : 0.267141
# batch 0 g_loss : 2.027542
# batch 1 d_loss : 0.307219
# batch 1 g_loss : 1.634625
# batch 2 d_loss : 0.289467
# batch 2 g_loss : 1.901012
# Epoch is 244
# Number of batches 3
# batch 0 d_loss : 0.281068
# batch 0 g_loss : 2.079230
# batch 1 d_loss : 0.269722
# batch 1 g_loss : 1.203685
# batch 2 d_loss : 0.256316
# batch 2 g_loss : 1.695161
# Epoch is 245
# Number of batches 3
# batch 0 d_loss : 0.196156
# batch 0 g_loss : 1.557051
# batch 1 d_loss : 0.313710
# batch 1 g_loss : 2.158685
# batch 2 d_loss : 0.242645
# batch 2 g_loss : 1.809608
# Epoch is 246
# Number of batches 3
# batch 0 d_loss : 0.188205
# batch 0 g_loss : 1.433392
# batch 1 d_loss : 0.207328
# batch 1 g_loss : 1.535095
# batch 2 d_loss : 0.206236
# batch 2 g_loss : 2.018422
# Epoch is 247
# Number of batches 3
# batch 0 d_loss : 0.189793
# batch 0 g_loss : 1.630393
# batch 1 d_loss : 0.271688
# batch 1 g_loss : 1.849096
# batch 2 d_loss : 0.284520
# batch 2 g_loss : 1.345586
# Epoch is 248
# Number of batches 3
# batch 0 d_loss : 0.214232
# batch 0 g_loss : 1.480524
# batch 1 d_loss : 0.306818
# batch 1 g_loss : 2.043833
# batch 2 d_loss : 0.247885
# batch 2 g_loss : 1.737920
# Epoch is 249
# Number of batches 3
# ...
# batch 1 d_loss : 0.152466
# batch 1 g_loss : 2.073928
# batch 2 d_loss : 0.307679
# batch 2 g_loss : 2.394479
# Epoch is 316
# Number of batches 3
# batch 0 d_loss : 0.163966
# batch 0 g_loss : 3.200042
# batch 1 d_loss : 0.116017
# batch 1 g_loss : 2.100294
# batch 2 d_loss : 0.252355
# batch 2 g_loss : 2.267428
# Epoch is 317
# Number of batches 3
# batch 0 d_loss : 0.184769
# batch 0 g_loss : 2.595462
# batch 1 d_loss : 0.213817
# batch 1 g_loss : 2.097074
# batch 2 d_loss : 0.143355
# batch 2 g_loss : 1.790579
# Epoch is 318
# Number of batches 3
# batch 0 d_loss : 0.130076
# batch 0 g_loss : 2.753821
# batch 1 d_loss : 0.168369
# batch 1 g_loss : 3.374142
# batch 2 d_loss : 0.203549
# batch 2 g_loss : 2.285069
# Epoch is 319
# Number of batches 3
# batch 0 d_loss : 0.236864
# batch 0 g_loss : 3.145493
# batch 1 d_loss : 0.195321
# batch 1 g_loss : 2.740822
# batch 2 d_loss : 0.175937
# batch 2 g_loss : 2.863586
# Epoch is 320
# Number of batches 3
# batch 0 d_loss : 0.149784
# batch 0 g_loss : 2.646234
# batch 1 d_loss : 0.136747
# batch 1 g_loss : 2.403648
# batch 2 d_loss : 0.326797
# batch 2 g_loss : 2.808197
# Epoch is 321
# Number of batches 3
# batch 0 d_loss : 0.177922
# batch 0 g_loss : 2.543133
# batch 1 d_loss : 0.204494
# batch 1 g_loss : 3.094214
# batch 2 d_loss : 0.147218
# batch 2 g_loss : 2.246333
# Epoch is 322
# Number of batches 3
# batch 0 d_loss : 0.306664
# batch 0 g_loss : 2.595102
# batch 1 d_loss : 0.133066
# batch 1 g_loss : 2.690903
# batch 2 d_loss : 0.204798
# batch 2 g_loss : 2.668364
# Epoch is 323
# Number of batches 3
# batch 0 d_loss : 0.194054
# batch 0 g_loss : 3.410284
# batch 1 d_loss : 0.121691
# batch 1 g_loss : 2.243246
# batch 2 d_loss : 0.118641
# batch 2 g_loss : 2.125316
# Epoch is 324
# Number of batches 3
# batch 0 d_loss : 0.252101
# batch 0 g_loss : 2.733435
# batch 1 d_loss : 0.148324
# batch 1 g_loss : 3.398487
# batch 2 d_loss : 0.171454
# batch 2 g_loss : 2.747034
# Epoch is 325
# Number of batches 3
# batch 0 d_loss : 0.192248
# batch 0 g_loss : 2.564089
# batch 1 d_loss : 0.089699
# batch 1 g_loss : 2.598686
# batch 2 d_loss : 0.254446
# batch 2 g_loss : 3.253117
# Epoch is 326
# Number of batches 3
# batch 0 d_loss : 0.192117
# batch 0 g_loss : 2.525915
# batch 1 d_loss : 0.223126
# batch 1 g_loss : 4.091678
# batch 2 d_loss : 0.244141
# batch 2 g_loss : 2.373385
# Epoch is 327
# Number of batches 3
# batch 0 d_loss : 0.194858
# batch 0 g_loss : 1.926799
# batch 1 d_loss : 0.151791
# batch 1 g_loss : 2.699733
# batch 2 d_loss : 0.238960
# batch 2 g_loss : 3.349708
# Epoch is 328
# Number of batches 3
# batch 0 d_loss : 0.188476
# batch 0 g_loss : 2.993340
# batch 1 d_loss : 0.165516
# batch 1 g_loss : 2.848127
# batch 2 d_loss : 0.141345
# batch 2 g_loss : 2.222568
# Epoch is 329
# Number of batches 3
# batch 0 d_loss : 0.300424
# batch 0 g_loss : 3.167658
# batch 1 d_loss : 0.125918
# batch 1 g_loss : 2.567477
# batch 2 d_loss : 0.133314
# batch 2 g_loss : 2.668766
# Epoch is 330
# Number of batches 3
# batch 0 d_loss : 0.210426
# batch 0 g_loss : 2.348133
# batch 1 d_loss : 0.135394
# batch 1 g_loss : 2.844993
# batch 2 d_loss : 0.136006
# batch 2 g_loss : 2.105468
# Epoch is 331
# Number of batches 3
# batch 0 d_loss : 0.131012
# batch 0 g_loss : 2.389152
# batch 1 d_loss : 0.180926
# batch 1 g_loss : 3.446723
# batch 2 d_loss : 0.158493
# batch 2 g_loss : 2.073590
# Epoch is 332
# Number of batches 3
# batch 0 d_loss : 0.263214
# batch 0 g_loss : 3.243177
# batch 1 d_loss : 0.109322
# batch 1 g_loss : 2.534438
# batch 2 d_loss : 0.150286
# batch 2 g_loss : 2.199049
# Epoch is 333
# Number of batches 3
# batch 0 d_loss : 0.132826
# batch 0 g_loss : 2.544951
# batch 1 d_loss : 0.163903
# batch 1 g_loss : 2.497340
# batch 2 d_loss : 0.141789
# batch 2 g_loss : 2.440829
# Epoch is 334
# Number of batches 3
# batch 0 d_loss : 0.169671
# batch 0 g_loss : 2.898987
# batch 1 d_loss : 0.166516
# batch 1 g_loss : 3.561354
# batch 2 d_loss : 0.157957
# batch 2 g_loss : 2.258473
# Epoch is 335
# Number of batches 3
# batch 0 d_loss : 0.184085
# batch 0 g_loss : 2.512584
# batch 1 d_loss : 0.172110
# batch 1 g_loss : 3.900305
# batch 2 d_loss : 0.146729
# batch 2 g_loss : 2.686578
# Epoch is 336
# Number of batches 3
# batch 0 d_loss : 0.210288
# batch 0 g_loss : 2.735357
# batch 1 d_loss : 0.127554
# batch 1 g_loss : 2.917689
# batch 2 d_loss : 0.137148
# batch 2 g_loss : 2.830590
# Epoch is 337
# Number of batches 3
# batch 0 d_loss : 0.208875
# batch 0 g_loss : 3.468022
# batch 1 d_loss : 0.105876
# batch 1 g_loss : 2.862651
# batch 2 d_loss : 0.090844
# batch 2 g_loss : 1.635661
# Epoch is 338
# Number of batches 3
# batch 0 d_loss : 0.268555
# batch 0 g_loss : 2.676069
# batch 1 d_loss : 0.103347
# batch 1 g_loss : 2.640173
# batch 2 d_loss : 0.165953
# batch 2 g_loss : 2.597057
# Epoch is 339
# Number of batches 3
# batch 0 d_loss : 0.133090
# batch 0 g_loss : 2.522356
# batch 1 d_loss : 0.156713
# batch 1 g_loss : 3.316709
# batch 2 d_loss : 0.162779
# batch 2 g_loss : 2.246763
# Epoch is 340
# Number of batches 3
# batch 0 d_loss : 0.191001
# batch 0 g_loss : 3.644698
# batch 1 d_loss : 0.115480
# batch 1 g_loss : 3.451306
# batch 2 d_loss : 0.150681
# batch 2 g_loss : 2.246471
# Epoch is 341
# Number of batches 3
# batch 0 d_loss : 0.135213
# batch 0 g_loss : 2.442863
# batch 1 d_loss : 0.111574
# batch 1 g_loss : 3.039880
# batch 2 d_loss : 0.116614
# batch 2 g_loss : 2.159616
# Epoch is 342
# Number of batches 3
# batch 0 d_loss : 0.163698
# batch 0 g_loss : 3.416432
# batch 1 d_loss : 0.074814
# batch 1 g_loss : 2.893729
# batch 2 d_loss : 0.123157
# batch 2 g_loss : 2.560179
# Epoch is 343
# Number of batches 3
# batch 0 d_loss : 0.196419
# batch 0 g_loss : 2.970203
# batch 1 d_loss : 0.095001
# batch 1 g_loss : 3.238399
# batch 2 d_loss : 0.126883
# batch 2 g_loss : 2.832487
# Epoch is 344
# Number of batches 3
# batch 0 d_loss : 0.131748
# batch 0 g_loss : 2.096608
# batch 1 d_loss : 0.107868
# batch 1 g_loss : 3.186231
# batch 2 d_loss : 0.252305
# batch 2 g_loss : 3.595868
# Epoch is 345
# Number of batches 3
# batch 0 d_loss : 0.290935
# batch 0 g_loss : 3.330255
# batch 1 d_loss : 0.080823
# batch 1 g_loss : 2.219856
# batch 2 d_loss : 0.097357
# batch 2 g_loss : 2.319714
# Epoch is 346
# Number of batches 3
# batch 0 d_loss : 0.178173
# batch 0 g_loss : 3.557246
# batch 1 d_loss : 0.083523
# batch 1 g_loss : 2.868362
# batch 2 d_loss : 0.154571
# batch 2 g_loss : 2.427698
# Epoch is 347
# Number of batches 3
# batch 0 d_loss : 0.149699
# batch 0 g_loss : 2.416255
# batch 1 d_loss : 0.208451
# batch 1 g_loss : 3.883310
# batch 2 d_loss : 0.231669
# batch 2 g_loss : 3.018143
# Epoch is 348
# Number of batches 3
# batch 0 d_loss : 0.142963
# batch 0 g_loss : 2.530668
# batch 1 d_loss : 0.146665
# batch 1 g_loss : 3.057189
# batch 2 d_loss : 0.153557
# batch 2 g_loss : 3.576286
# Epoch is 349
# Number of batches 3
# batch 0 d_loss : 0.127203
# batch 0 g_loss : 2.803211
# batch 1 d_loss : 0.120549
# batch 1 g_loss : 3.483362
# batch 2 d_loss : 0.113033
# batch 2 g_loss : 2.690402
# Epoch is 350
# Number of batches 3
# batch 0 d_loss : 0.123352
# batch 0 g_loss : 2.692098
# batch 1 d_loss : 0.169733
# batch 1 g_loss : 4.111323
# batch 2 d_loss : 0.127370
# batch 2 g_loss : 2.648094
# Epoch is 351
# Number of batches 3
# batch 0 d_loss : 0.148709
# batch 0 g_loss : 2.843858
# batch 1 d_loss : 0.208444
# batch 1 g_loss : 3.960860
# batch 2 d_loss : 0.147998
# batch 2 g_loss : 2.584518
# Epoch is 352
# Number of batches 3
# batch 0 d_loss : 0.152342
# batch 0 g_loss : 2.480790
# batch 1 d_loss : 0.148273
# batch 1 g_loss : 2.690135
# batch 2 d_loss : 0.143663
# batch 2 g_loss : 3.408070
# Epoch is 353
# Number of batches 3
# batch 0 d_loss : 0.183409
# batch 0 g_loss : 3.163343
# batch 1 d_loss : 0.188189
# batch 1 g_loss : 2.668565
# batch 2 d_loss : 0.125913
# batch 2 g_loss : 3.021740
# Epoch is 354
# Number of batches 3
# batch 0 d_loss : 0.145759
# batch 0 g_loss : 3.347543
# batch 1 d_loss : 0.141387
# batch 1 g_loss : 3.113550
# batch 2 d_loss : 0.083748
# batch 2 g_loss : 2.448133
# Epoch is 355
# Number of batches 3
# batch 0 d_loss : 0.138843
# batch 0 g_loss : 3.096281
# batch 1 d_loss : 0.216899
# batch 1 g_loss : 3.590321
# batch 2 d_loss : 0.098812
# batch 2 g_loss : 3.533180
# Epoch is 356
# Number of batches 3
# batch 0 d_loss : 0.140120
# batch 0 g_loss : 2.802816
# batch 1 d_loss : 0.076737
# batch 1 g_loss : 2.425625
# batch 2 d_loss : 0.123533
# batch 2 g_loss : 3.494706
# Epoch is 357
# Number of batches 3
# batch 0 d_loss : 0.116833
# batch 0 g_loss : 2.758283
# batch 1 d_loss : 0.121815
# batch 1 g_loss : 2.399386
# batch 2 d_loss : 0.144116
# batch 2 g_loss : 3.873315
# Epoch is 358
# Number of batches 3
# batch 0 d_loss : 0.125502
# batch 0 g_loss : 2.858713
# batch 1 d_loss : 0.104096
# batch 1 g_loss : 2.553442
# batch 2 d_loss : 0.073163
# batch 2 g_loss : 2.192681
# Epoch is 359
# Number of batches 3
# batch 0 d_loss : 0.169939
# batch 0 g_loss : 2.751081
# batch 1 d_loss : 0.116297
# batch 1 g_loss : 2.601642
# batch 2 d_loss : 0.134209
# batch 2 g_loss : 3.530437
# Epoch is 360
# Number of batches 3
# batch 0 d_loss : 0.258028
# batch 0 g_loss : 3.822508
# batch 1 d_loss : 0.154266
# batch 1 g_loss : 2.269130
# batch 2 d_loss : 0.125821
# batch 2 g_loss : 2.702597
# Epoch is 361
# Number of batches 3
# batch 0 d_loss : 0.144404
# batch 0 g_loss : 2.713014
# batch 1 d_loss : 0.121938
# batch 1 g_loss : 3.463184
# batch 2 d_loss : 0.135024
# batch 2 g_loss : 2.759836
# Epoch is 362
# Number of batches 3
# batch 0 d_loss : 0.130572
# batch 0 g_loss : 2.858240
# batch 1 d_loss : 0.215680
# batch 1 g_loss : 3.960304
# batch 2 d_loss : 0.214072
# batch 2 g_loss : 3.820245
# Epoch is 363
# Number of batches 3
# batch 0 d_loss : 0.118412
# batch 0 g_loss : 2.536729
# batch 1 d_loss : 0.149036
# batch 1 g_loss : 2.843286
# batch 2 d_loss : 0.114744
# batch 2 g_loss : 2.578571
# Epoch is 364
# Number of batches 3
# batch 0 d_loss : 0.116215
# batch 0 g_loss : 2.867841
# batch 1 d_loss : 0.142795
# batch 1 g_loss : 3.373869
# batch 2 d_loss : 0.137508
# batch 2 g_loss : 2.950565
# Epoch is 365
# Number of batches 3
# batch 0 d_loss : 0.103861
# batch 0 g_loss : 2.473325
# batch 1 d_loss : 0.113354
# batch 1 g_loss : 2.655065
# batch 2 d_loss : 0.119316
# batch 2 g_loss : 2.290669
# Epoch is 366
# Number of batches 3
# batch 0 d_loss : 0.183473
# batch 0 g_loss : 3.441152
# batch 1 d_loss : 0.162392
# batch 1 g_loss : 3.404977
# batch 2 d_loss : 0.143090
# batch 2 g_loss : 2.618726
# Epoch is 367
# Number of batches 3
# batch 0 d_loss : 0.135900
# batch 0 g_loss : 2.661295
# batch 1 d_loss : 0.103055
# batch 1 g_loss : 3.658984
# batch 2 d_loss : 0.126292
# batch 2 g_loss : 2.907032
# Epoch is 368
# Number of batches 3
# batch 0 d_loss : 0.136198
# batch 0 g_loss : 2.944177
# batch 1 d_loss : 0.082755
# batch 1 g_loss : 2.666907
# batch 2 d_loss : 0.114084
# batch 2 g_loss : 1.972512
# Epoch is 369
# Number of batches 3
# batch 0 d_loss : 0.161413
# batch 0 g_loss : 3.129494
# batch 1 d_loss : 0.153340
# batch 1 g_loss : 3.170294
# batch 2 d_loss : 0.138391
# batch 2 g_loss : 2.382977
# Epoch is 370
# Number of batches 3
# batch 0 d_loss : 0.117701
# batch 0 g_loss : 2.324962
# batch 1 d_loss : 0.091515
# batch 1 g_loss : 2.389539
# batch 2 d_loss : 0.171524
# batch 2 g_loss : 3.255848
# Epoch is 371
# Number of batches 3
# batch 0 d_loss : 0.145031
# batch 0 g_loss : 3.265329
# batch 1 d_loss : 0.174662
# batch 1 g_loss : 3.709431
# batch 2 d_loss : 0.144961
# batch 2 g_loss : 2.351172
# Epoch is 372
# Number of batches 3
# batch 0 d_loss : 0.134329
# batch 0 g_loss : 2.511851
# batch 1 d_loss : 0.073481
# batch 1 g_loss : 2.812526
# batch 2 d_loss : 0.065871
# batch 2 g_loss : 1.944770
# Epoch is 373
# Number of batches 3
# batch 0 d_loss : 0.133952
# batch 0 g_loss : 2.240891
# batch 1 d_loss : 0.152915
# batch 1 g_loss : 3.956879
# batch 2 d_loss : 0.181298
# batch 2 g_loss : 3.400384
# Epoch is 374
# Number of batches 3
# batch 0 d_loss : 0.153632
# batch 0 g_loss : 2.723260
# batch 1 d_loss : 0.130651
# batch 1 g_loss : 3.021762
# batch 2 d_loss : 0.126824
# batch 2 g_loss : 3.829910
# Epoch is 375
# Number of batches 3
# batch 0 d_loss : 0.131422
# batch 0 g_loss : 2.928401
# batch 1 d_loss : 0.167557
# batch 1 g_loss : 2.992930
# batch 2 d_loss : 0.108671
# batch 2 g_loss : 3.512282
# Epoch is 376
# Number of batches 3
# batch 0 d_loss : 0.103107
# batch 0 g_loss : 3.203625
# batch 1 d_loss : 0.089584
# batch 1 g_loss : 2.654360
# batch 2 d_loss : 0.147788
# batch 2 g_loss : 2.598783
# Epoch is 377
# Number of batches 3
# batch 0 d_loss : 0.111773
# batch 0 g_loss : 3.579144
# batch 1 d_loss : 0.073017
# batch 1 g_loss : 2.687968
# batch 2 d_loss : 0.130948
# batch 2 g_loss : 2.994107
# Epoch is 378
# Number of batches 3
# batch 0 d_loss : 0.096360
# batch 0 g_loss : 3.007472
# batch 1 d_loss : 0.115954
# batch 1 g_loss : 3.544994
# batch 2 d_loss : 0.112465
# batch 2 g_loss : 3.796153
# Epoch is 379
# Number of batches 3
# batch 0 d_loss : 0.149580
# batch 0 g_loss : 3.242577
# batch 1 d_loss : 0.110515
# batch 1 g_loss : 2.916461
# batch 2 d_loss : 0.137999
# batch 2 g_loss : 2.900118
# Epoch is 380
# Number of batches 3
# batch 0 d_loss : 0.097776
# batch 0 g_loss : 2.923734
# batch 1 d_loss : 0.102047
# batch 1 g_loss : 2.661623
# batch 2 d_loss : 0.091226
# batch 2 g_loss : 2.832515
# Epoch is 381
# Number of batches 3
# batch 0 d_loss : 0.103726
# batch 0 g_loss : 3.362291
# batch 1 d_loss : 0.086411
# batch 1 g_loss : 2.749208
# batch 2 d_loss : 0.109728
# batch 2 g_loss : 3.353901
# Epoch is 382
# Number of batches 3
# batch 0 d_loss : 0.192232
# batch 0 g_loss : 4.154093
# batch 1 d_loss : 0.140935
# batch 1 g_loss : 3.180055
# batch 2 d_loss : 0.117149
# batch 2 g_loss : 2.856609
# Epoch is 383
# Number of batches 3
# batch 0 d_loss : 0.100143
# batch 0 g_loss : 2.469031
# batch 1 d_loss : 0.068761
# batch 1 g_loss : 2.845002
# batch 2 d_loss : 0.133775
# batch 2 g_loss : 3.361762
# Epoch is 384
# Number of batches 3
# batch 0 d_loss : 0.153374
# batch 0 g_loss : 3.157050
# batch 1 d_loss : 0.132928
# batch 1 g_loss : 3.272388
# batch 2 d_loss : 0.125518
# batch 2 g_loss : 4.004882
# Epoch is 385
# Number of batches 3
# batch 0 d_loss : 0.145904
# batch 0 g_loss : 3.307213
# batch 1 d_loss : 0.083766
# batch 1 g_loss : 2.719983
# batch 2 d_loss : 0.204964
# batch 2 g_loss : 4.107271
# Epoch is 386
# Number of batches 3
# batch 0 d_loss : 0.121646
# batch 0 g_loss : 3.399574
# batch 1 d_loss : 0.134831
# batch 1 g_loss : 2.973877
# batch 2 d_loss : 0.141063
# batch 2 g_loss : 3.301521
# Epoch is 387
# Number of batches 3
# batch 0 d_loss : 0.105689
# batch 0 g_loss : 3.146674
# batch 1 d_loss : 0.101410
# batch 1 g_loss : 3.543992
# batch 2 d_loss : 0.092199
# batch 2 g_loss : 2.118197
# Epoch is 388
# Number of batches 3
# batch 0 d_loss : 0.082264
# batch 0 g_loss : 2.542486
# batch 1 d_loss : 0.185017
# batch 1 g_loss : 3.416235
# batch 2 d_loss : 0.129868
# batch 2 g_loss : 2.707924
# Epoch is 389
# Number of batches 3
# batch 0 d_loss : 0.081980
# batch 0 g_loss : 2.195755
# batch 1 d_loss : 0.089469
# batch 1 g_loss : 2.264407
# batch 2 d_loss : 0.183930
# batch 2 g_loss : 2.828013
# Epoch is 390
# Number of batches 3
# batch 0 d_loss : 0.137518
# batch 0 g_loss : 3.579468
# batch 1 d_loss : 0.126349
# batch 1 g_loss : 2.935093
# batch 2 d_loss : 0.152413
# batch 2 g_loss : 3.661914
# Epoch is 391
# Number of batches 3
# batch 0 d_loss : 0.115969
# batch 0 g_loss : 2.958712
# batch 1 d_loss : 0.104792
# batch 1 g_loss : 3.707450
# batch 2 d_loss : 0.077444
# batch 2 g_loss : 2.834242
# Epoch is 392
# Number of batches 3
# batch 0 d_loss : 0.167573
# batch 0 g_loss : 3.413344
# batch 1 d_loss : 0.075425
# batch 1 g_loss : 3.699921
# batch 2 d_loss : 0.114394
# batch 2 g_loss : 3.452021
# Epoch is 393
# Number of batches 3
# batch 0 d_loss : 0.121394
# batch 0 g_loss : 2.670513
# batch 1 d_loss : 0.209962
# batch 1 g_loss : 3.960820
# batch 2 d_loss : 0.164387
# batch 2 g_loss : 3.047945
# Epoch is 394
# Number of batches 3
# batch 0 d_loss : 0.132839
# batch 0 g_loss : 2.920641
# batch 1 d_loss : 0.084748
# batch 1 g_loss : 3.330678
# batch 2 d_loss : 0.083101
# batch 2 g_loss : 3.022659
# Epoch is 395
# Number of batches 3
# batch 0 d_loss : 0.209323
# batch 0 g_loss : 4.389356
# batch 1 d_loss : 0.131559
# batch 1 g_loss : 3.251202
# batch 2 d_loss : 0.099528
# batch 2 g_loss : 2.932229
# Epoch is 396
# Number of batches 3
# batch 0 d_loss : 0.127110
# batch 0 g_loss : 2.306334
# batch 1 d_loss : 0.062618
# batch 1 g_loss : 3.246945
# batch 2 d_loss : 0.135499
# batch 2 g_loss : 2.867904
# Epoch is 397
# Number of batches 3
# batch 0 d_loss : 0.122298
# batch 0 g_loss : 3.608536
# batch 1 d_loss : 0.092313
# batch 1 g_loss : 3.914169
# batch 2 d_loss : 0.089927
# batch 2 g_loss : 2.787604
# Epoch is 398
# Number of batches 3
# batch 0 d_loss : 0.160434
# batch 0 g_loss : 3.061663
# batch 1 d_loss : 0.074665
# batch 1 g_loss : 3.257565
# batch 2 d_loss : 0.103618
# batch 2 g_loss : 3.228687
# Epoch is 399
# Number of batches 3
# batch 0 d_loss : 0.100913
# batch 0 g_loss : 2.267249
# batch 1 d_loss : 0.101695
# batch 1 g_loss : 3.305295
# batch 2 d_loss : 0.169343
# batch 2 g_loss : 4.316561

# %%
generate(1)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]
# 1/1 [==============================] - 0s
# (1, 1, 128, 128)
