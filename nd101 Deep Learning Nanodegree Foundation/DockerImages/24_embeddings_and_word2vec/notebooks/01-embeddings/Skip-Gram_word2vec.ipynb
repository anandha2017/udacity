# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:18, 1.72MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
print(int_words[:30])
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx -R) >0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6573 0.2027 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5806 0.1979 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4717 0.1999 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5834 0.1968 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5023 0.1965 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5350 0.1976 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5411 0.1960 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5668 0.1976 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4830 0.1978 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4606 0.1973 sec/batch
# Nearest to by: nontechnical, stadium, pointe, jani, minh, dr, griffith, grieving,
# Nearest to see: imperfections, caucasians, eric, heisenberg, princeto, rpgs, kwon, weevil,
# Nearest to zero: parsing, fanpage, fading, tsonga, ormers, arguing, lds, reston,
# Nearest to it: grams, mind, spelt, laurie, theodosian, booty, fleet, oddly,
# Nearest to s: exaggerates, bale, scoring, duress, redshift, yakima, auratus, supplies,
# Nearest to its: collectivized, prototyping, mozambique, microkernel, cd, desmond, karelian, submergence,
# Nearest to has: colecovision, frog, greuze, deimos, counterproductive, homoerotic, females, tiepolo,
# Nearest to most: equally, byzantine, gratis, parliaments, bombings, corporation, cornwall, argos,
# Nearest to test: spare, dunn, lha, berwickshire, fronds, baiting, killings, alm,
# Nearest to applications: kinematics, slanted, unranked, cultivated, telangana, eleanor, delicately, pok,
# Nearest to issue: uwe, mee, ammonia, titan, bonnie, zog, information, theodor,
# Nearest to resources: wargame, stacey, distorts, andronicus, outwardly, pastiches, autarky, pragmatically,
# Nearest to http: microlensing, tiny, judas, latinos, iconoclasm, ground, impurities, befell,
# Nearest to active: accountant, laboured, baseman, budo, colman, frontend, driessen, grows,
# Nearest to units: muggles, oldest, disinfectant, misses, bursts, ancona, magick, ridden,
# Nearest to behind: wigner, marsilio, murabitun, along, scotia, pontifex, sugarcubes, christianization,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4942 0.1940 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3941 0.1873 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3487 0.1876 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2399 0.1877 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1625 0.1874 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1796 0.1996 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0779 0.2098 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0575 0.2069 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9891 0.2095 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9677 0.2085 sec/batch
# Nearest to by: stadium, nontechnical, dr, perceived, minh, pointe, partly, ordinary,
# Nearest to see: heisenberg, caucasians, eric, imperfections, the, significant, programming, colleges,
# Nearest to zero: parsing, arguing, lds, household, fading, adopted, shared, steward,
# Nearest to it: mind, state, grams, theodosian, laurie, beat, uprisings, fleet,
# Nearest to s: scoring, exaggerates, once, supplies, guinea, sides, bale, o,
# Nearest to its: collectivized, designed, cd, mm, desmond, prototyping, mozambique, tes,
# Nearest to has: now, frog, females, counterproductive, countries, greuze, deimos, agriculture,
# Nearest to most: equally, byzantine, parliaments, corporation, gratis, bombings, prohibition, socially,
# Nearest to test: lha, spare, dunn, berwickshire, killings, fossil, costing, functioned,
# Nearest to applications: slanted, cultivated, adequately, baldwin, dec, methods, chandler, signers,
# Nearest to issue: information, what, uwe, errors, titan, mee, theodor, ancient,
# Nearest to resources: wargame, distorts, outwardly, stacey, remnants, subdue, provides, pragmatically,
# Nearest to http: tiny, microlensing, latinos, ground, judas, impurities, provide, iconoclasm,
# Nearest to active: colman, cove, baseman, laboured, frontend, grows, accountant, suffer,
# Nearest to units: muggles, oldest, symbolism, bursts, misses, expression, libertarian, ancona,
# Nearest to behind: along, scotia, wigner, murabitun, marsilio, slipping, core, sugarcubes,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9501 0.2117 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9111 0.1945 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8767 0.2032 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8680 0.2074 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7889 0.1963 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8170 0.1946 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8052 0.1943 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7893 0.1931 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7765 0.2011 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8010 0.2053 sec/batch
# Nearest to by: stadium, nontechnical, partly, dr, distant, minh, perceived, ordinary,
# Nearest to see: heisenberg, imperfections, caucasians, eric, programming, invasions, significant, the,
# Nearest to zero: parsing, household, constantin, steward, stalin, kampf, arguing, ormers,
# Nearest to it: mind, grams, state, laurie, weapon, ensemble, uprisings, galaxies,
# Nearest to s: scoring, exaggerates, guinea, earl, bale, sides, supplies, hippopotamus,
# Nearest to its: prototyping, collectivized, desmond, transactions, mozambique, confidence, cd, microkernel,
# Nearest to has: counterproductive, frog, now, greuze, penciller, females, agriculture, threats,
# Nearest to most: equally, parliaments, byzantine, gratis, bombings, corporation, naturalistic, socially,
# Nearest to test: spare, lha, dunn, killings, costing, fossil, pilot, integration,
# Nearest to applications: slanted, cultivated, adequately, baldwin, chandler, signers, pok, dec,
# Nearest to issue: uwe, information, errors, what, titan, bonnie, mee, grammatically,
# Nearest to resources: distorts, wargame, stacey, pastiches, subdue, pragmatically, outwardly, remnants,
# Nearest to http: microlensing, latinos, tiny, judas, ground, iconoclasm, impurities, mutants,
# Nearest to active: grows, frontend, cove, baseman, colman, inside, laboured, suffer,
# Nearest to units: muggles, oldest, misses, symbolism, ridden, bursts, expression, missions,
# Nearest to behind: along, scotia, wigner, murabitun, marsilio, slipping, core, christianization,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7890 0.2076 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7276 0.2033 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7490 0.2040 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7351 0.2040 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7367 0.2031 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7159 0.2036 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7078 0.2031 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7000 0.2028 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6868 0.2041 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6438 0.2029 sec/batch
# Nearest to by: stadium, minh, partly, perceived, nontechnical, dr, griffith, distant,
# Nearest to see: imperfections, heisenberg, caucasians, prakrit, rpgs, fillmore, invasions, significant,
# Nearest to zero: one, stalin, household, switzerland, constantin, parsing, kampf, steward,
# Nearest to it: oddly, grams, weapon, mind, galaxies, ensemble, state, entries,
# Nearest to s: exaggerates, guinea, earl, scoring, abc, quinn, bale, demise,
# Nearest to its: prototyping, collectivized, desmond, transactions, mozambique, confidence, microkernel, cd,
# Nearest to has: counterproductive, greuze, penciller, calibrated, plundered, calder, deimos, fricative,
# Nearest to most: equally, parliaments, byzantine, gratis, naturalistic, intractable, socially, bombings,
# Nearest to test: spare, costing, berwickshire, lha, killings, baiting, dunn, integration,
# Nearest to applications: slanted, adequately, pok, dec, cultivated, methods, signers, floor,
# Nearest to issue: titan, uwe, bonnie, grammatically, ammonia, mee, lingus, what,
# Nearest to resources: distorts, pragmatically, wargame, stacey, pastiches, subdue, chants, crops,
# Nearest to http: microlensing, latinos, tiny, judas, gagarin, swedish, collingridge, burks,
# Nearest to active: grows, laboured, baseman, frontend, colman, suffer, fins, inside,
# Nearest to units: muggles, misses, oldest, adsorption, symbolism, bursts, ridden, expression,
# Nearest to behind: scotia, along, wigner, murabitun, marsilio, slipping, tickets, pontifex,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6697 0.2040 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6698 0.2022 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6281 0.2046 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6115 0.2032 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6528 0.2035 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6438 0.2029 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5771 0.1466 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5574 0.2029 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5594 0.2014 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5261 0.2010 sec/batch
# Nearest to by: stadium, partly, rhodesia, minh, nontechnical, perceived, griffith, confesses,
# Nearest to see: imperfections, caucasians, heisenberg, prakrit, rpgs, candida, fillmore, bot,
# Nearest to zero: one, constantin, steward, household, parsing, stalin, wto, loyola,
# Nearest to it: oddly, weapon, grams, galaxies, mind, em, uprisings, ensemble,
# Nearest to s: exaggerates, guinea, prd, titicaca, scoring, quinn, bale, coventry,
# Nearest to its: prototyping, mozambique, transactions, collectivized, desmond, confidence, microkernel, iarc,
# Nearest to has: counterproductive, penciller, calibrated, greuze, countries, telescoping, now, tiepolo,
# Nearest to most: equally, gratis, parliaments, byzantine, intractable, naturalistic, lukas, socially,
# Nearest to test: spare, costing, berwickshire, fronds, gadget, baiting, lha, dunn,
# Nearest to applications: slanted, methods, adequately, floor, dec, enumeration, pok, utc,
# Nearest to issue: titan, ammonia, grammatically, mee, uwe, zog, lingus, divine,
# Nearest to resources: pragmatically, stacey, distorts, andronicus, crops, pastiches, wargame, gauss,
# Nearest to http: microlensing, latinos, gagarin, tiny, appian, swedish, judas, collingridge,
# Nearest to active: grows, laboured, inside, baseman, budo, accountant, frontend, fins,
# Nearest to units: muggles, misses, calculated, adsorption, oldest, bursts, expression, missions,
# Nearest to behind: scotia, murabitun, along, tickets, wigner, marsilio, pontifex, tawhid,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4810 0.2024 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4794 0.1999 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4408 0.2008 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5175 0.2001 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4771 0.2004 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4784 0.2005 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4685 0.2006 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4248 0.1988 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4160 0.1998 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4217 0.2002 sec/batch
# Nearest to by: stadium, partly, nontechnical, perceived, rhodesia, confesses, dutiful, contraception,
# Nearest to see: imperfections, heisenberg, caucasians, prakrit, candida, fillmore, rpgs, bot,
# Nearest to zero: household, one, two, four, wto, constantin, million, six,
# Nearest to it: oddly, galaxies, entries, grams, weapon, mind, spelt, particles,
# Nearest to s: exaggerates, titicaca, bale, guinea, prd, backpack, warranties, abc,
# Nearest to its: prototyping, transactions, collectivized, mozambique, confidence, microkernel, sector, iarc,
# Nearest to has: countries, counterproductive, calibrated, penciller, telescoping, greuze, exporter, belarusian,
# Nearest to most: equally, gratis, parliaments, byzantine, naturalistic, intractable, lukas, tikal,
# Nearest to test: spare, costing, fronds, berwickshire, baiting, safely, lha, gadget,
# Nearest to applications: methods, slanted, adequately, operating, enumeration, dec, system, gaps,
# Nearest to issue: titan, ammonia, lingus, mee, uwe, zog, grammatically, what,
# Nearest to resources: crops, forests, petroleum, pragmatically, agriculture, stacey, diversified, subdue,
# Nearest to http: microlensing, latinos, com, appian, www, forum, gagarin, swedish,
# Nearest to active: laboured, grows, inside, fins, fed, accountant, baseman, target,
# Nearest to units: misses, muggles, adsorption, calculated, taito, isotherm, disinfectant, viscous,
# Nearest to behind: murabitun, scotia, along, wigner, tickets, marsilio, pontifex, normed,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4287 0.2022 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3997 0.2008 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4318 0.1987 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3983 0.2028 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4029 0.1975 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4308 0.1992 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3620 0.2018 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3962 0.1997 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3977 0.1996 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3953 0.2001 sec/batch
# Nearest to by: nontechnical, perceived, rhodesia, dutiful, stadium, partly, belongings, biot,
# Nearest to see: imperfections, heisenberg, caucasians, prakrit, candida, bot, divisions, fillmore,
# Nearest to zero: one, two, household, four, six, constantin, million, eight,
# Nearest to it: oddly, mind, em, spelt, galaxies, represent, uprisings, ensemble,
# Nearest to s: exaggerates, bale, prd, titicaca, guinea, backpack, of, earl,
# Nearest to its: prototyping, transactions, collectivized, mozambique, confidence, desmond, microkernel, canadians,
# Nearest to has: countries, counterproductive, telescoping, calibrated, rundown, penciller, distilling, tiepolo,
# Nearest to most: equally, gratis, parliaments, byzantine, intractable, naturalistic, lukas, displayed,
# Nearest to test: spare, safely, baiting, costing, fronds, pilot, gadget, lha,
# Nearest to applications: slanted, operating, adequately, dec, methods, gaps, enumeration, system,
# Nearest to issue: ammonia, lingus, titan, zog, validity, mee, elicited, what,
# Nearest to resources: crops, forests, petroleum, agriculture, pragmatically, eckernf, diversified, pastiches,
# Nearest to http: com, microlensing, www, latinos, forum, bibliography, appian, edu,
# Nearest to active: laboured, inside, rubbing, gaining, fed, hilltop, fins, regulates,
# Nearest to units: adsorption, misses, calculated, taito, muggles, viscous, disinfectant, powered,
# Nearest to behind: along, murabitun, scotia, tickets, pontifex, marsilio, wigner, normed,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3881 0.2006 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4037 0.2035 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3529 0.2009 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3777 0.2000 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3787 0.2004 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3765 0.2007 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3849 0.1982 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3706 0.2011 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3085 0.2028 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3221 0.1981 sec/batch
# Nearest to by: perceived, rhodesia, nontechnical, dutiful, nationalised, genosha, partly, ninth,
# Nearest to see: imperfections, prakrit, caucasians, heisenberg, candida, divisions, bot, cairn,
# Nearest to zero: one, two, four, six, five, household, three, eight,
# Nearest to it: oddly, mind, horned, em, inclusion, entries, weapon, grams,
# Nearest to s: bale, of, commissioner, carniola, exaggerates, backpack, prd, coventry,
# Nearest to its: prototyping, confidence, transactions, collectivized, mozambique, microkernel, superbly, desmond,
# Nearest to has: countries, counterproductive, telescoping, calibrated, rundown, exporter, agriculture, medicines,
# Nearest to most: equally, gratis, byzantine, intractable, parliaments, naturalistic, lukas, slavish,
# Nearest to test: spare, safely, pilot, costing, fronds, baiting, lha, gadget,
# Nearest to applications: operating, slanted, gaps, dec, adequately, gsm, utc, liquids,
# Nearest to issue: lingus, ammonia, zog, titan, validity, views, elicited, what,
# Nearest to resources: crops, forests, petroleum, agriculture, pragmatically, eckernf, stacey, diametrically,
# Nearest to http: com, microlensing, www, forum, edu, org, latinos, bibliography,
# Nearest to active: laboured, inside, rubbing, regulates, cristae, fed, plancherel, gaining,
# Nearest to units: adsorption, misses, taito, calculated, powered, muggles, missions, isotherm,
# Nearest to behind: scotia, murabitun, tickets, along, pontifex, tawhid, marsilio, wigner,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3502 0.2037 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2824 0.2015 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3671 0.2014 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4005 0.1997 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3740 0.1972 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2955 0.2004 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2833 0.1986 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3640 0.1997 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2261 0.2020 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2956 0.2006 sec/batch
# Nearest to by: rhodesia, perceived, nontechnical, genosha, nationalised, minh, dutiful, ayurvedic,
# Nearest to see: imperfections, prakrit, divisions, heisenberg, caucasians, candida, list, bot,
# Nearest to zero: two, one, five, four, six, household, three, eight,
# Nearest to it: oddly, inclusion, mind, entries, em, grams, rodeo, imperfections,
# Nearest to s: of, carniola, prd, backpack, commissioner, exaggerates, coventry, second,
# Nearest to its: prototyping, collectivized, transactions, confidence, mozambique, desmond, superbly, microkernel,
# Nearest to has: countries, telescoping, calibrated, himalaya, belarusian, rundown, counterproductive, era,
# Nearest to most: equally, gratis, byzantine, naturalistic, intractable, displayed, parliaments, iberia,
# Nearest to test: spare, gadget, fronds, baiting, pilot, safely, costing, lha,
# Nearest to applications: operating, slanted, adequately, dec, gaps, gsm, environments, utc,
# Nearest to issue: lingus, titan, zog, ammonia, validity, views, elicited, mee,
# Nearest to resources: crops, forests, petroleum, agriculture, pragmatically, stacey, provides, eckernf,
# Nearest to http: com, www, edu, forum, microlensing, bilingual, org, latinos,
# Nearest to active: laboured, rubbing, inside, cristae, gaining, regulates, fed, fallback,
# Nearest to units: taito, misses, adsorption, muggles, calculated, powered, isotherm, disinfectant,
# Nearest to behind: tickets, murabitun, pontifex, tawhid, scotia, along, slipping, picked,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3012 0.2033 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3020 0.1985 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3261 0.0844 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2311 0.1902 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2550 0.1912 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2111 0.1915 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2128 0.1905 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1960 0.1903 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2311 0.1900 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1794 0.1905 sec/batch
# Nearest to by: rhodesia, genosha, nontechnical, nationalised, perceived, ninth, belongings, partly,
# Nearest to see: imperfections, heisenberg, prakrit, caucasians, divisions, candida, bot, cairn,
# Nearest to zero: two, one, four, six, five, three, household, eight,
# Nearest to it: oddly, inclusion, entries, em, spelt, indentured, rodeo, horned,
# Nearest to s: backpack, prd, of, carniola, guinea, commissioner, exaggerates, coventry,
# Nearest to its: prototyping, collectivized, transactions, confidence, mozambique, superbly, microkernel, canadians,
# Nearest to has: countries, telescoping, belarusian, calibrated, intercity, rundown, major, era,
# Nearest to most: equally, gratis, byzantine, displayed, appellant, intractable, naturalistic, slavish,
# Nearest to test: spare, pilot, safely, gadget, costing, berwickshire, fronds, baiting,
# Nearest to applications: operating, slanted, unix, adequately, dec, gsm, introduction, gaps,
# Nearest to issue: titan, lingus, zog, ammonia, validity, mee, elicited, what,
# Nearest to resources: crops, forests, petroleum, agriculture, pragmatically, provides, diametrically, diversified,
# Nearest to http: com, www, edu, forum, microlensing, bilingual, html, org,
# Nearest to active: inside, laboured, fed, gaining, fallback, nontoxic, rubbing, cristae,
# Nearest to units: taito, misses, adsorption, powered, missions, calculated, viscous, muggles,
# Nearest to behind: murabitun, tickets, along, slipping, pontifex, scotia, picked, tawhid,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2197 0.1967 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2203 0.1907 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2205 0.1907 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1360 0.1908 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1775 0.1912 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1787 0.1905 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1709 0.1904 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1668 0.1895 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2001 0.1910 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1793 0.1919 sec/batch
# Nearest to by: genosha, nontechnical, jani, perceived, rhodesia, terraforming, haki, ayurvedic,
# Nearest to see: imperfections, heisenberg, prakrit, candida, caucasians, cairn, bot, divisions,
# Nearest to zero: two, one, six, four, five, three, household, nine,
# Nearest to it: oddly, inclusion, entries, galaxies, particles, em, spelt, grams,
# Nearest to s: of, carniola, backpack, shrinks, tangential, cataclysmic, guinea, commissioner,
# Nearest to its: prototyping, confidence, collectivized, transactions, microkernel, desmond, ashram, unifies,
# Nearest to has: countries, telescoping, calibrated, belarusian, conventions, penciller, rundown, era,
# Nearest to most: equally, gratis, displayed, tikal, sagittarius, byzantine, slavish, naturalistic,
# Nearest to test: spare, pilot, baiting, gadget, safely, lha, cancelled, fronds,
# Nearest to applications: operating, adequately, slanted, introduction, dec, unix, alt, gsm,
# Nearest to issue: lingus, titan, ammonia, zog, validity, elicited, information, defendants,
# Nearest to resources: crops, forests, petroleum, provides, pragmatically, agriculture, stacey, eckernf,
# Nearest to http: com, www, edu, forum, bilingual, microlensing, org, html,
# Nearest to active: inside, laboured, fallback, gaining, rubbing, cristae, fed, hilltop,
# Nearest to units: taito, misses, adsorption, isotherm, calculated, disinfectant, muggles, powered,
# Nearest to behind: murabitun, tickets, along, slipping, pontifex, picked, scotia, marsilio,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1914 0.1922 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2242 0.1907 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1605 0.1931 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1687 0.2006 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1869 0.1909 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1748 0.1916 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1899 0.1906 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1505 0.1898 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1507 0.1924 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1611 0.1910 sec/batch
# Nearest to by: genosha, rhodesia, perceived, jani, the, terraforming, ninth, rearranged,
# Nearest to see: imperfections, heisenberg, prakrit, divisions, caucasians, candida, cairn, bot,
# Nearest to zero: two, one, six, five, four, three, nine, years,
# Nearest to it: inclusion, oddly, utilitarian, entries, rodeo, horned, em, oddparents,
# Nearest to s: of, carniola, guinea, bale, backpack, second, cataclysmic, amitabh,
# Nearest to its: prototyping, collectivized, confidence, transactions, unifies, desmond, superbly, microkernel,
# Nearest to has: countries, conventions, belarusian, telescoping, nasalized, calibrated, product, decibel,
# Nearest to most: equally, gratis, tikal, naturalistic, displayed, slavish, byzantine, sagittarius,
# Nearest to test: spare, pilot, safely, lha, dunn, gadget, cancelled, baiting,
# Nearest to applications: operating, adequately, slanted, unix, introduction, methods, gaps, dec,
# Nearest to issue: zog, lingus, titan, ammonia, validity, views, information, elicited,
# Nearest to resources: crops, forests, petroleum, provides, agriculture, issues, pragmatically, pineapples,
# Nearest to http: com, www, edu, forum, org, bilingual, htm, html,
# Nearest to active: inside, laboured, fallback, sanatan, gaining, cristae, hilltop, rubbing,
# Nearest to units: taito, adsorption, misses, isotherm, disinfectant, missions, calculated, viscous,
# Nearest to behind: murabitun, along, tickets, slipping, pontifex, picked, scotia, marsilio,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1888 0.1936 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1564 0.1919 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1714 0.1915 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2153 0.1915 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1456 0.1912 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1313 0.1920 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1575 0.1916 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1300 0.1918 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2180 0.1912 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2163 0.1922 sec/batch
# Nearest to by: rhodesia, the, genosha, perceived, ninth, jani, dr, haki,
# Nearest to see: imperfections, prakrit, divisions, heisenberg, list, candida, caucasians, tertius,
# Nearest to zero: two, one, six, five, four, nine, three, eight,
# Nearest to it: oddly, inclusion, utilitarian, rodeo, horned, uprisings, entries, falsificationism,
# Nearest to s: of, carniola, amitabh, bale, backpack, earl, contemporary, coventry,
# Nearest to its: collectivized, prototyping, confidence, transactions, desmond, superbly, unifies, mozambique,
# Nearest to has: countries, conventions, belarusian, telescoping, banquets, exploiting, era, penciller,
# Nearest to most: equally, gratis, iberia, tikal, sven, naturalistic, byzantine, animist,
# Nearest to test: spare, pilot, gadget, agreements, baiting, lha, costing, fronds,
# Nearest to applications: operating, adequately, unix, introduction, slanted, dec, gaps, alt,
# Nearest to issue: titan, zog, lingus, ammonia, information, validity, percentile, views,
# Nearest to resources: crops, forests, petroleum, issues, provides, agriculture, pragmatically, pineapples,
# Nearest to http: com, www, edu, forum, htm, bilingual, org, html,
# Nearest to active: laboured, sanatan, inside, fallback, cristae, gaining, amino, rubbing,
# Nearest to units: taito, misses, adsorption, isotherm, weights, zeeland, missions, quelling,
# Nearest to behind: murabitun, along, tickets, slipping, scotia, pontifex, picked, tawhid,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1983 0.1928 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1378 0.1908 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1389 0.1903 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1410 0.1905 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0535 0.1915 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1428 0.1900 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1353 0.1907 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1346 0.1915 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1863 0.0307 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1370 0.1900 sec/batch
# Nearest to by: rhodesia, the, genosha, ninth, jani, nationalised, nontechnical, rearranged,
# Nearest to see: imperfections, divisions, prakrit, list, heisenberg, candida, caucasians, tertius,
# Nearest to zero: two, one, six, five, four, three, nine, eight,
# Nearest to it: oddly, rodeo, utilitarian, inclusion, em, entries, particles, if,
# Nearest to s: of, carniola, prd, amitabh, guinea, backpack, tangential, second,
# Nearest to its: prototyping, collectivized, confidence, transactions, unifies, superbly, desmond, mauritian,
# Nearest to has: penciller, telescoping, conventions, belarusian, celebrities, himalaya, countries, homoerotic,
# Nearest to most: gratis, equally, displayed, sven, slavish, iberia, byzantine, tikal,
# Nearest to test: spare, pilot, agreements, gadget, costing, lha, cancelled, baiting,
# Nearest to applications: adequately, operating, slanted, introduction, dec, unix, alt, api,
# Nearest to issue: zog, ammonia, titan, elicited, lingus, validity, information, views,
# Nearest to resources: crops, petroleum, forests, dolomite, issues, stacey, provides, pineapples,
# Nearest to http: www, com, edu, forum, htm, bilingual, org, html,
# Nearest to active: fallback, laboured, inside, sanatan, cristae, amino, gaining, nrc,
# Nearest to units: taito, weights, calculated, misses, adsorption, zeeland, isotherm, missions,
# Nearest to behind: murabitun, slipping, picked, along, tickets, pushes, pontifex, scotia,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0968 0.2004 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0948 0.1916 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0687 0.1909 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0749 0.1899 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0685 0.1916 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0370 0.1913 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0917 0.1902 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0950 0.1903 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1082 0.1902 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0529 0.1917 sec/batch
# Nearest to by: rhodesia, the, perceived, genosha, rearranged, jani, and, ninth,
# Nearest to see: imperfections, divisions, prakrit, candida, list, tertius, heisenberg, caucasians,
# Nearest to zero: two, one, six, four, three, five, nine, eight,
# Nearest to it: oddly, em, from, rodeo, purring, inclusion, brett, spelt,
# Nearest to s: of, carniola, guinea, contemporary, cataclysmic, prd, second, lucca,
# Nearest to its: prototyping, collectivized, confidence, superbly, desmond, transactions, overlooking, mauritian,
# Nearest to has: conventions, telescoping, belarusian, countries, cities, celebrities, penciller, himalaya,
# Nearest to most: equally, gratis, disproportionate, slavish, sven, tikal, iberia, byzantine,
# Nearest to test: spare, pilot, safely, agreements, cancelled, lha, gadget, baiting,
# Nearest to applications: operating, adequately, slanted, introduction, unix, zilog, dec, alt,
# Nearest to issue: titan, ammonia, percentile, elicited, zog, lingus, information, mandriva,
# Nearest to resources: crops, forests, issues, petroleum, dolomite, provides, pineapples, agriculture,
# Nearest to http: www, com, edu, forum, htm, org, bilingual, html,
# Nearest to active: inside, laboured, nontoxic, fallback, amino, cristae, sanatan, cisleithania,
# Nearest to units: taito, weights, isotherm, calculated, adsorption, misses, conversion, dzerzhinsky,
# Nearest to behind: murabitun, slipping, along, pushes, picked, tickets, pontifex, marsilio,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0387 0.1939 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0046 0.1909 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0079 0.2027 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0593 0.1933 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0364 0.1915 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0492 0.1919 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0546 0.1915 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1039 0.1912 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0543 0.1891 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0229 0.1901 sec/batch
# Nearest to by: the, rhodesia, rearranged, beehive, ninth, genosha, jani, perceived,
# Nearest to see: imperfections, divisions, list, prakrit, tertius, heisenberg, candida, blockbusters,
# Nearest to zero: two, one, four, six, three, five, nine, eight,
# Nearest to it: oddly, utilitarian, em, from, brett, purring, entries, inclusion,
# Nearest to s: of, carniola, guinea, cataclysmic, lucca, second, quad, shrinks,
# Nearest to its: prototyping, confidence, collectivized, desmond, atacama, favour, superbly, transactions,
# Nearest to has: himalaya, telescoping, conventions, decibel, countries, belarusian, calibrated, nasalized,
# Nearest to most: equally, gratis, slavish, tikal, sven, aromatics, disproportionate, displayed,
# Nearest to test: spare, pilot, safely, agreements, lha, baiting, gadget, brushed,
# Nearest to applications: operating, slanted, introduction, adequately, unix, dec, methods, alt,
# Nearest to issue: ammonia, titan, elicited, percentile, lingus, zog, views, mandriva,
# Nearest to resources: issues, crops, forests, petroleum, provides, dolomite, environment, stacey,
# Nearest to http: www, com, edu, forum, htm, bilingual, org, html,
# Nearest to active: inside, cristae, sanatan, fallback, laboured, amino, cisleithania, gaining,
# Nearest to units: taito, weights, isotherm, calculated, adsorption, bf, dzerzhinsky, conversion,
# Nearest to behind: slipping, murabitun, along, pushes, picked, marsilio, tickets, pontifex,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0678 0.1929 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1041 0.1910 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0746 0.1909 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0460 0.1906 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0661 0.1899 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0450 0.1894 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.1106 0.1894 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0195 0.1907 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0621 0.1909 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0597 0.1909 sec/batch
# Nearest to by: the, rhodesia, and, ninth, nationalised, incursion, perceived, genosha,
# Nearest to see: imperfections, divisions, list, prakrit, tertius, external, candida, cairn,
# Nearest to zero: two, one, six, three, four, five, nine, eight,
# Nearest to it: oddly, from, utilitarian, inclusion, em, brett, purring, entries,
# Nearest to s: of, cataclysmic, carniola, laughton, amitabh, lucca, reviews, guinea,
# Nearest to its: collectivized, desmond, confidence, prototyping, atacama, superbly, showing, transactions,
# Nearest to has: conventions, himalaya, banquets, udi, countries, belarusian, celebrities, roster,
# Nearest to most: equally, gratis, slavish, sven, disproportionate, byzantine, iberia, animist,
# Nearest to test: spare, pilot, agreements, lha, safely, baiting, brushed, gadget,
# Nearest to applications: operating, adequately, slanted, introduction, unix, dec, methods, alt,
# Nearest to issue: titan, ammonia, views, percentile, elicited, zog, devasting, information,
# Nearest to resources: issues, forests, crops, petroleum, dolomite, provides, articles, pragmatically,
# Nearest to http: www, com, edu, forum, htm, html, org, bilingual,
# Nearest to active: inside, sanatan, laboured, amino, fallback, cristae, cisleithania, nrc,
# Nearest to units: weights, taito, isotherm, calculated, adsorption, dzerzhinsky, bf, conversion,
# Nearest to behind: murabitun, slipping, along, picked, pushes, scotia, pontifex, gait,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0488 0.1922 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9902 0.1896 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0295 0.1897 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0675 0.1924 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1000 0.1929 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1431 0.1915 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1123 0.1901 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0429 0.1921 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0453 0.1913 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0726 0.1908 sec/batch
# Nearest to by: the, rhodesia, and, nationalised, perceived, ninth, genosha, rearranged,
# Nearest to see: imperfections, divisions, list, prakrit, tertius, candida, cairn, lema,
# Nearest to zero: two, one, six, five, nine, three, four, eight,
# Nearest to it: oddly, brett, em, from, inclusion, utilitarian, purring, true,
# Nearest to s: of, carniola, second, laughton, guinea, obvious, majorities, lucca,
# Nearest to its: collectivized, desmond, confidence, prototyping, showing, superbly, atacama, amended,
# Nearest to has: celebrities, conventions, belarusian, himalaya, roster, countries, cities, nasalized,
# Nearest to most: equally, gratis, slavish, sven, disproportionate, iberia, as, animist,
# Nearest to test: spare, agreements, pilot, safely, lha, gadget, baiting, haer,
# Nearest to applications: operating, adequately, unix, introduction, slanted, dec, alt, api,
# Nearest to issue: titan, ammonia, percentile, elicited, lingus, zog, devasting, mandriva,
# Nearest to resources: issues, forests, crops, dolomite, petroleum, environment, provides, pragmatically,
# Nearest to http: www, com, edu, htm, org, forum, bilingual, html,
# Nearest to active: inside, laboured, sanatan, fallback, cisleithania, amino, cristae, nrc,
# Nearest to units: weights, taito, dzerzhinsky, calculated, isotherm, si, adsorption, bf,
# Nearest to behind: slipping, murabitun, along, picked, pushes, pontifex, gait, scotia,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9733 0.1940 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0313 0.1914 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0180 0.1919 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0542 0.1908 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0644 0.1900 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0352 0.1675 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0202 0.1918 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9823 0.1919 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0496 0.1898 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9976 0.1902 sec/batch
# Nearest to by: the, and, rhodesia, rearranged, jani, staring, genosha, ninth,
# Nearest to see: imperfections, divisions, list, prakrit, tertius, candida, external, lema,
# Nearest to zero: two, six, one, four, three, five, nine, eight,
# Nearest to it: brett, oddly, em, from, horned, inclusion, entries, purring,
# Nearest to s: of, carniola, ihr, guinea, second, laughton, lucca, buyers,
# Nearest to its: prototyping, collectivized, desmond, confidence, showing, sponsorship, resulting, superbly,
# Nearest to has: celebrities, conventions, himalaya, nasalized, roster, homoerotic, jouvenel, cities,
# Nearest to most: equally, gratis, slavish, sven, disproportionate, iberia, as, animist,
# Nearest to test: pilot, spare, agreements, safely, lha, gadget, ppg, baiting,
# Nearest to applications: introduction, adequately, operating, slanted, unix, alt, gaps, methods,
# Nearest to issue: titan, ammonia, elicited, percentile, lingus, zog, astronomers, bans,
# Nearest to resources: crops, forests, issues, dolomite, petroleum, environment, provides, pragmatically,
# Nearest to http: www, com, edu, htm, forum, org, bilingual, html,
# Nearest to active: inside, laboured, fallback, cisleithania, nontoxic, sanatan, cristae, aloe,
# Nearest to units: weights, taito, dzerzhinsky, calculated, si, bf, adsorption, curried,
# Nearest to behind: murabitun, slipping, pushes, along, picked, gait, milos, pontifex,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0004 0.1925 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9538 0.1918 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0274 0.1896 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0341 0.1923 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0222 0.1908 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0012 0.1911 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9246 0.1899 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 4.0050 0.1906 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9408 0.1900 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9674 0.1895 sec/batch
# Nearest to by: the, rhodesia, and, jani, rearranged, perceived, genosha, lining,
# Nearest to see: imperfections, list, divisions, lema, tertius, candida, external, cairn,
# Nearest to zero: two, one, six, four, three, five, nine, eight,
# Nearest to it: from, brett, oddly, em, baghdad, if, the, guilder,
# Nearest to s: of, guinea, second, ihr, main, carniola, exaggerates, buyers,
# Nearest to its: desmond, collectivized, prototyping, confidence, showing, resulting, atacama, sponsorship,
# Nearest to has: conventions, himalaya, cities, celebrities, major, udi, belarusian, roster,
# Nearest to most: equally, gratis, slavish, disproportionate, as, sven, usually, socially,
# Nearest to test: agreements, safely, spare, pilot, ppg, gadget, brushed, lha,
# Nearest to applications: introduction, operating, adequately, slanted, unix, methods, prentice, alt,
# Nearest to issue: ammonia, elicited, titan, percentile, astronomers, bans, lingus, devasting,
# Nearest to resources: crops, forests, issues, dolomite, environment, provides, petroleum, hazards,
# Nearest to http: www, com, edu, htm, forum, org, bilingual, html,
# Nearest to active: inside, fallback, cristae, cisleithania, aloe, nrc, nontoxic, laboured,
# Nearest to units: weights, taito, dzerzhinsky, cavalry, si, isotherm, calculated, bf,
# Nearest to behind: murabitun, slipping, along, pushes, picked, milos, gait, reflected,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9675 0.1933 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0060 0.1914 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9629 0.1908 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0078 0.1925 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0389 0.1894 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9484 0.1909 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9973 0.1908 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9910 0.1903 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9527 0.1912 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9980 0.1897 sec/batch
# Nearest to by: the, rhodesia, and, with, jani, perceived, rearranged, nationalised,
# Nearest to see: imperfections, list, divisions, lema, external, tertius, candida, of,
# Nearest to zero: two, one, six, four, five, three, nine, eight,
# Nearest to it: from, oddly, brett, utilitarian, the, true, entries, em,
# Nearest to s: of, second, carniola, following, the, guinea, main, laughton,
# Nearest to its: desmond, collectivized, confidence, sponsorship, showing, favour, prototyping, resulting,
# Nearest to has: conventions, is, roster, celebrities, major, nasalized, udi, jouvenel,
# Nearest to most: equally, gratis, slavish, disproportionate, as, sven, unambiguously, socially,
# Nearest to test: agreements, safely, spare, ppg, dunn, pilot, gadget, baiting,
# Nearest to applications: operating, introduction, adequately, slanted, unix, application, methods, alt,
# Nearest to issue: ammonia, elicited, bans, percentile, titan, astronomers, lingus, views,
# Nearest to resources: crops, forests, issues, dolomite, petroleum, provides, environment, hazards,
# Nearest to http: www, com, edu, htm, forum, org, html, bilingual,
# Nearest to active: inside, fallback, sanatan, laboured, cristae, nrc, cisleithania, aloe,
# Nearest to units: weights, taito, dzerzhinsky, si, calculated, cavalry, bf, isotherm,
# Nearest to behind: slipping, murabitun, along, picked, pushes, milos, reflected, gait,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0114 0.1933 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9897 0.1909 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0060 0.1906 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0202 0.1909 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0155 0.1912 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9732 0.1917 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9939 0.1906 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9474 0.1922 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9693 0.1903 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0194 0.1936 sec/batch
# Nearest to by: the, rhodesia, and, nationalised, incursion, perceived, jani, with,
# Nearest to see: list, imperfections, divisions, external, lema, tertius, candida, of,
# Nearest to zero: two, six, one, five, four, three, nine, eight,
# Nearest to it: brett, from, oddly, the, baghdad, beneficiary, inclusion, entries,
# Nearest to s: of, second, carniola, main, following, the, ihr, majorities,
# Nearest to its: desmond, collectivized, confidence, resulting, of, prototyping, the, showing,
# Nearest to has: conventions, jouvenel, is, celebrities, major, belarusian, nasalized, udi,
# Nearest to most: equally, gratis, slavish, as, disproportionate, iberia, unambiguously, tikal,
# Nearest to test: agreements, safely, spare, ppg, dunn, icao, dumping, baiting,
# Nearest to applications: operating, introduction, unix, adequately, slanted, application, dec, alt,
# Nearest to issue: ammonia, percentile, elicited, lingus, titan, bans, devasting, mandriva,
# Nearest to resources: crops, forests, issues, dolomite, petroleum, environment, provides, pragmatically,
# Nearest to http: www, com, edu, htm, org, forum, html, bilingual,
# Nearest to active: inside, sanatan, amino, laboured, nrc, cisleithania, cristae, aloe,
# Nearest to units: weights, dzerzhinsky, si, calculated, taito, cavalry, bf, giambattista,
# Nearest to behind: slipping, murabitun, gait, along, reflected, pushes, picked, milos,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9846 0.1943 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1055 0.1916 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0409 0.1911 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0519 0.1980 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9543 0.1916 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9447 0.1902 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9833 0.1911 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9331 0.1914 sec/batch
# ...
# Nearest to active: inside, nontoxic, hypro, laboured, sophomore, imperfective, aloe, konix,
# Nearest to units: weights, giambattista, si, cavalry, residing, syst, taito, dzerzhinsky,
# Nearest to behind: slipping, located, reflected, gouraud, pushes, agis, milos, murabitun,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8849 0.1958 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7616 0.1924 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8491 0.1908 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8125 0.1895 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7986 0.1899 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8341 0.1907 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8559 0.1902 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8110 0.1898 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8624 0.1899 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9302 0.1912 sec/batch
# Nearest to by: the, and, a, with, for, of, s, as,
# Nearest to see: of, list, external, also, the, lema, links, is,
# Nearest to zero: two, six, one, four, five, three, nine, eight,
# Nearest to it: in, the, from, is, was, which, to, brett,
# Nearest to s: of, the, was, a, that, and, on, second,
# Nearest to its: the, with, desmond, as, which, resulting, this, showing,
# Nearest to has: is, been, as, also, casein, alphabetical, webmasters, there,
# Nearest to most: as, other, usually, disproportionate, than, its, were, relocated,
# Nearest to test: agreements, ppg, safely, tests, src, haer, dumping, testing,
# Nearest to applications: application, unix, operating, blog, telangana, leonardo, homeric, spirituality,
# Nearest to issue: ammonia, favoring, percentile, bans, astronomers, khanate, terminator, mandriva,
# Nearest to resources: petroleum, page, resource, forests, hutchinson, provides, crops, hydropower,
# Nearest to http: www, com, htm, edu, org, forum, docs, html,
# Nearest to active: inside, nontoxic, hypro, sophomore, aloe, laboured, imperfective, gaining,
# Nearest to units: weights, giambattista, cavalry, si, residing, taito, syst, dzerzhinsky,
# Nearest to behind: slipping, located, reflected, gouraud, pushes, oblique, firefox, milos,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7899 0.1930 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8444 0.1995 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8783 0.1906 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8359 0.1919 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8642 0.1908 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8720 0.1908 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8564 0.1916 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8556 0.1892 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8789 0.1899 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8480 0.1918 sec/batch
# Nearest to by: the, and, of, a, with, rhodesia, for, is,
# Nearest to see: of, list, external, also, the, links, is, lema,
# Nearest to zero: two, six, one, five, three, four, nine, seven,
# Nearest to it: the, which, in, from, to, was, is, a,
# Nearest to s: of, the, was, a, that, on, and, in,
# Nearest to its: the, which, with, desmond, resulting, as, a, this,
# Nearest to has: is, been, as, also, casein, alphabetical, recent, however,
# Nearest to most: as, other, usually, disproportionate, slavish, than, many, considered,
# Nearest to test: agreements, safely, src, ppg, tests, haer, testing, dumping,
# Nearest to applications: application, unix, blog, telangana, leonardo, homeric, operating, properties,
# Nearest to issue: ammonia, favoring, percentile, bans, relegating, placing, aretz, astronomers,
# Nearest to resources: petroleum, hydropower, forests, quarried, crops, page, provides, resource,
# Nearest to http: www, com, htm, edu, org, docs, forum, html,
# Nearest to active: inside, hypro, laboured, nontoxic, sophomore, amino, rda, gaining,
# Nearest to units: giambattista, weights, cavalry, si, residing, taito, conversion, syst,
# Nearest to behind: slipping, located, reflected, agis, pushes, abelard, oblique, firefox,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8585 0.1948 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8611 0.1907 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8064 0.1917 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8535 0.1989 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8968 0.1917 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8330 0.1939 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9606 0.1916 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8866 0.1904 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9268 0.1920 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8232 0.1914 sec/batch
# Nearest to by: the, and, a, of, with, for, rhodesia, one,
# Nearest to see: list, of, external, also, the, links, lema, redirects,
# Nearest to zero: two, six, one, three, five, four, nine, eight,
# Nearest to it: the, which, to, was, is, in, from, that,
# Nearest to s: of, the, was, a, on, that, second, and,
# Nearest to its: the, with, which, this, and, desmond, of, as,
# Nearest to has: is, been, as, alphabetical, also, have, there, casein,
# Nearest to most: as, other, usually, disproportionate, considered, many, although, mossi,
# Nearest to test: agreements, tests, safely, src, ppg, testing, dumping, modification,
# Nearest to applications: application, unix, blog, telangana, operating, leonardo, homeric, microsoft,
# Nearest to issue: ammonia, favoring, percentile, relegating, bans, aretz, woodward, astronomers,
# Nearest to resources: petroleum, hydropower, crops, forests, quarried, hutchinson, dolomite, issues,
# Nearest to http: www, com, htm, edu, org, docs, html, forum,
# Nearest to active: inside, sophomore, nontoxic, hypro, laboured, gaining, rda, konix,
# Nearest to units: giambattista, weights, cavalry, si, residing, taito, conversion, islander,
# Nearest to behind: slipping, reflected, located, agis, abelard, chased, warlike, firefox,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7810 0.1913 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8780 0.1910 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7731 0.1918 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8752 0.1915 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8359 0.1915 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8259 0.1900 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8927 0.0917 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8112 0.1916 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8328 0.1909 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8228 0.1927 sec/batch
# Nearest to by: the, and, of, a, with, rhodesia, for, conversion,
# Nearest to see: list, of, external, also, the, links, lema, redirects,
# Nearest to zero: two, six, one, four, five, three, nine, eight,
# Nearest to it: the, which, was, from, to, is, in, a,
# Nearest to s: of, was, the, that, a, on, and, second,
# Nearest to its: the, with, which, as, is, it, desmond, this,
# Nearest to has: is, been, as, casein, alphabetical, however, there, interchangeable,
# Nearest to most: as, other, usually, disproportionate, considered, many, slavish, than,
# Nearest to test: tests, agreements, safely, src, ppg, haer, testing, baiting,
# Nearest to applications: application, unix, operating, telangana, leonardo, microsoft, blog, spirituality,
# Nearest to issue: ammonia, favoring, percentile, relegating, terminator, placing, khanate, zombies,
# Nearest to resources: petroleum, hydropower, crops, hutchinson, quarried, forests, dolomite, page,
# Nearest to http: www, com, htm, edu, org, docs, html, forum,
# Nearest to active: inside, sophomore, nontoxic, laboured, gaining, highest, konix, hypro,
# Nearest to units: giambattista, si, weights, cavalry, residing, taito, syst, conversion,
# Nearest to behind: slipping, located, reflected, oblique, abelard, agis, pushes, firefox,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8280 0.1941 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8252 0.1914 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8517 0.1993 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7755 0.1912 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8523 0.1907 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8431 0.1907 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8645 0.1926 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7476 0.1932 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8296 0.1912 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8050 0.1917 sec/batch
# Nearest to by: the, and, of, a, for, with, as, is,
# Nearest to see: of, list, also, external, the, links, history, nine,
# Nearest to zero: two, six, one, four, five, three, nine, eight,
# Nearest to it: which, the, is, to, in, from, a, its,
# Nearest to s: of, the, a, was, and, that, on, in,
# Nearest to its: the, with, as, is, a, it, of, which,
# Nearest to has: is, been, as, also, there, alphabetical, since, major,
# Nearest to most: as, other, usually, than, disproportionate, have, and, many,
# Nearest to test: tests, agreements, safely, testing, src, haer, ppg, baiting,
# Nearest to applications: application, unix, leonardo, telangana, properties, distorts, abe, spirituality,
# Nearest to issue: ammonia, favoring, percentile, aretz, terminator, zombies, khanate, bans,
# Nearest to resources: hydropower, crops, petroleum, quarried, provides, hutchinson, forests, issues,
# Nearest to http: www, com, htm, edu, org, docs, html, forum,
# Nearest to active: inside, nontoxic, sophomore, highest, imperfective, hypro, gaining, rda,
# Nearest to units: giambattista, cavalry, weights, si, taito, residing, conversion, unit,
# Nearest to behind: slipping, reflected, located, firefox, oblique, milos, pushes, lion,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7684 0.1931 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8214 0.1899 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8513 0.1916 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8089 0.1925 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8189 0.1907 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8742 0.1919 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8336 0.1926 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7931 0.1913 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8353 0.1992 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8467 0.1921 sec/batch
# Nearest to by: the, and, a, of, for, with, is, rhodesia,
# Nearest to see: of, list, also, external, the, links, is, lema,
# Nearest to zero: two, six, one, four, nine, three, five, eight,
# Nearest to it: is, which, the, to, in, a, from, was,
# Nearest to s: of, the, a, was, in, and, on, second,
# Nearest to its: the, with, is, which, a, of, it, as,
# Nearest to has: is, been, as, however, also, since, major, there,
# Nearest to most: as, other, usually, than, although, have, considered, many,
# Nearest to test: agreements, safely, tests, src, testing, haer, ppg, modification,
# Nearest to applications: application, unix, leonardo, properties, telangana, distorts, tec, spirituality,
# Nearest to issue: ammonia, favoring, key, bans, aretz, percentile, terminator, astronomers,
# Nearest to resources: hydropower, resource, petroleum, hutchinson, crops, provides, quarried, klan,
# Nearest to http: www, com, htm, edu, org, docs, html, forum,
# Nearest to active: inside, sophomore, imperfective, nontoxic, rda, highest, laboured, hypro,
# Nearest to units: giambattista, cavalry, weights, si, taito, residing, conversion, bf,
# Nearest to behind: slipping, reflected, located, firefox, oblique, pushes, gouraud, milos,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8927 0.1945 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8158 0.1898 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8101 0.1915 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8437 0.1907 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8824 0.1904 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8547 0.1922 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8545 0.1915 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8491 0.1920 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8113 0.1916 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7833 0.1914 sec/batch
# Nearest to by: the, and, a, of, with, for, is, rhodesia,
# Nearest to see: of, list, also, the, external, links, is, and,
# Nearest to zero: two, six, one, five, four, three, nine, eight,
# Nearest to it: the, which, in, is, to, from, a, was,
# Nearest to s: of, the, a, was, on, in, and, main,
# Nearest to its: the, with, is, which, of, as, a, it,
# Nearest to has: is, been, as, however, have, also, since, it,
# Nearest to most: as, other, disproportionate, its, many, usually, than, have,
# Nearest to test: agreements, safely, testing, tests, src, haer, ppg, baiting,
# Nearest to applications: application, unix, leonardo, telangana, homeric, blog, environments, operating,
# Nearest to issue: ammonia, favoring, bans, key, percentile, relegating, aretz, terminator,
# Nearest to resources: hydropower, petroleum, resource, hutchinson, quarried, crops, klan, articles,
# Nearest to http: www, htm, com, edu, org, docs, html, forum,
# Nearest to active: inside, hypro, nontoxic, sophomore, rda, imperfective, gaining, amino,
# Nearest to units: giambattista, weights, cavalry, si, residing, taito, conversion, dzerzhinsky,
# Nearest to behind: slipping, located, firefox, reflected, oblique, warlike, agis, abelard,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8559 0.1940 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8300 0.1929 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9031 0.1932 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9071 0.1936 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8676 0.1929 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8443 0.1913 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8075 0.1918 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8303 0.1906 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7321 0.1924 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8556 0.1915 sec/batch
# Nearest to by: the, and, of, rhodesia, with, a, for, s,
# Nearest to see: of, list, also, external, the, links, an, is,
# Nearest to zero: two, one, three, four, nine, five, six, seven,
# Nearest to it: is, which, the, to, was, in, from, a,
# Nearest to s: of, the, a, in, was, and, on, that,
# Nearest to its: the, with, is, as, which, of, and, a,
# Nearest to has: is, been, as, have, alphabetical, recent, however, since,
# Nearest to most: as, other, usually, many, disproportionate, considered, and, have,
# Nearest to test: testing, tests, agreements, src, safely, ppg, haer, modification,
# Nearest to applications: application, unix, environments, homeric, telangana, properties, spirituality, blog,
# Nearest to issue: favoring, ammonia, aretz, key, zombies, terminator, relegating, placing,
# Nearest to resources: hydropower, petroleum, quarried, crops, hutchinson, resource, issues, page,
# Nearest to http: www, htm, com, edu, org, docs, html, forum,
# Nearest to active: inside, sophomore, rda, imperfective, nontoxic, gaining, konix, hypro,
# Nearest to units: si, giambattista, weights, cavalry, residing, unit, taito, syst,
# Nearest to behind: slipping, firefox, reflected, oblique, warlike, located, gouraud, milos,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8291 0.1942 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8368 0.1907 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
